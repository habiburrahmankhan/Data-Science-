# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
def readData(filename):
    df = pd.read_csv(filename)
    return df.values
x = readData("../practice/data/linearX.csv")
y = readData("../practice/data/linearY.csv")
x = x.reshape((99,))
y = y.reshape((99,))

# %%
plt.scatter(x , y)

# %%
x = x - x.mean() / (x.std()) 
plt.scatter(x, y)

# %%
# Out:
# 99
