# %% [markdown]
# # List and Tuple

# %% [markdown]
# ### List

# %%
a = ["name " , 1 , 2.3 , "name33343"]

# %%
print(a)
# Out:
# ['name ', 1, 2.3, 'name33343']

# %%
type(a)
# Out:
# list

# %% [markdown]
# ### tuple

# %%
a = (2,3,5,6)

# %%
a = 2 , 3, 4 ,5

# %% [markdown]
# ### we can also  iniliase a tuple above

# %%
print(a)
# Out:
# (2, 3, 4, 5)

# %%
type(a)
# Out:
# tuple

# %%
print(type(a))
# Out:
# <class 'tuple'>

# %%
a = 10 
b = 20

# %%
a , b  = b ,a

# %% [markdown]
# ### in background a , b = 20 , 10   a and b assign to (20 , 10) a tuple is created .

# %%
print(a ,"  " ,  b)
# Out:
# 20    10

# %%
a = 10 
b = 20 
def swap (a , b):
    return b , a

# %%
a , b = swap(a , b)

# %% [markdown]
# ### a tuple is created in background    in return b , a

# %%
print(a , b)
# Out:
# 20 10

# %% [markdown]
# ## is operater
# ### is operator checks whether both the operands refer to the same object or not.

# %%
a = (4 , 5 ,6)

# %%
b = [4 , 5, 6]
c = a

# %%
a is b
# Out:
# False

# %%
a is c
# Out:
# True

# %%
a == b
# Out:
# False

# %%
a = [4 , 5 ,6 ]
b = [4 ,  5, 6 ]

# %%
a.append(a)

# %%
print(a)
# Out:
# [4, 5, 6, [...]]

# %%
a[-1]
# Out:
# [4, 5, 6, [...]]

# %%
a[-1][-1]
# Out:
# [4, 5, 6, [...]]

# %%
a[-1][-1][-1]
# Out:
# [4, 5, 6, [...]]

# %%
a[-1][-1][-1]
# Out:
# [4, 5, 6, [...]]

# %%
a.append(b)

# %%
print(a)
# Out:
# [4, 5, 6, [...], [4, 5, 6]]

# %% [markdown]
# ## Dictionary

# %%
d = {}

# %%
d["Apple"] = "A Sweet Red Fruit"

# %%
d["Mango"] = "A king of Fruit "

# %%
print(d)
# Out:
# {'Apple': 'A Sweet Red Fruit', 'Mango': 'A king of Fruit '}

# %%
print(d["Apple"])
# Out:
# A Sweet Red Fruit

# %%
"guava" in d
# Out:
# False

# %%
"Apple" in d
# Out:
# True

# %%
line = "I am a  programmer "
freq = {}
for ch in line.lower():
    if(ch not in  freq):
        freq[ch] =  1
    else:
        freq[ch] += 1 
print(freq)
# Out:
# {'i': 1, ' ': 5, 'a': 3, 'm': 3, 'p': 1, 'r': 3, 'o': 1, 'g': 1, 'e': 1}

# %%
print(freq.keys())
print(type(freq.keys()))
# Out:
# dict_keys(['i', ' ', 'a', 'm', 'p', 'r', 'o', 'g', 'e'])
# <class 'dict_keys'>

# %%
print(freq.values())
# Out:
# dict_values([1, 5, 3, 3, 1, 3, 1, 1, 1])

# %%
print(freq.items())
# Out:
# dict_items([('i', 1), (' ', 5), ('a', 3), ('m', 3), ('p', 1), ('r', 3), ('o', 1), ('g', 1), ('e', 1)])

# %%
tups = [('i', 1), (' ', 5 ), ('a', 3), ('m', 3), ('p', 1), ('r', 3), ('o', 1), ('g', 1), ('e', 1)]

# %%
di = dict(tups)

# %%
print(di)
# Out:
# {'i': 1, ' ': 5, 'a': 3, 'm': 3, 'p': 1, 'r': 3, 'o': 1, 'g': 1, 'e': 1}

# %% [markdown]
# ### Comprehensions

# %%
li = list(range(10 ,20))

# %%
[item**2 for item in li if item %3 == 0]
# Out:
# [144, 225, 324]

# %%
[item*3 for item in li if item %2 ==0]
# Out:
# [30, 36, 42, 48, 54]

# %% [markdown]
# ### Set

# %%
s = set()

# %%
s.add(5)

# %%
print(s, type(s))
# Out:
# {5} <class 'set'>

# %%
s = "hello"
s = set(s)

# %%
s = list(s)
s.sort()

# %%
print(s , type(s))
# Out:
# ['e', 'h', 'l', 'o'] <class 'list'>

# %%
f = open("happy.txt" , "wt")

# %%
f.writable()
# Out:
# True

# %%
f.write("let me finish my work ")
# Out:
# 22

# %%
f.close()   ## f.flush()

# %%
# %pwd
# Out:
# '/Users/habiburrahmankhan/datascience'

# %% [markdown]
# ### Writing a file

# %% [markdown]
# - write
# - writelines

# %% [markdown]
# ### Reading from a file

# %% [markdown]
# - read
# - readline
# - readlines

# %%
f = open("happy.txt" ,"rt")

# %%
f.read()
# Out:
# 'let me finish my work \naa\nddf\ng\nf\ng\ngh\ndsder\nh\ngh\ng\n'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# 'let me finish my work \n'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readlines()
# Out:
# ['let me finish my work \n',
#  'aa\n',
#  'ddf\n',
#  'g\n',
#  'f\n',
#  'g\n',
#  'gh\n',
#  'dsder\n',
#  'h\n',
#  'gh\n',
#  'g\n']

# %%
f.close()

# %%
import json

# %%
d = {"name" : "Mohit" , "Age" : 30 ,"class" : "12th" }

# %%
st = json.dumps(d)

# %%
json.loads(st)
# Out:
# {'name': 'Mohit', 'Age': 30, 'class': '12th'}

# %%
with open("happy" ,"wt") as fp : 
    st = json.dump(d , fp)
print(fp.closed)
# Out:
# True

# %%
with open("happy" ,"rt") as fp : 
    print(json.load(fp))
print(fp.closed)
# Out:
# {'name': 'Mohit', 'Age': 30, 'class': '12th'}
# True

# %% [markdown]
# ## download image from web to a file

# %%
import requests

# %%
link = r"https://images-na.ssl-images-amazon.com/images/S/sgp-catalog-images/region_US/dreamworks-11795-Full-Image_GalleryBackground-en-US-1483994504900._SX1080_.jpg"

# %%
data  =requests.get(link)

# %%
with open("panda.jpeg", "wb") as pfile:
    pfile.write(data.content)

# %% [markdown]
# ## download speech text  from web to a file

# %%
link = r"https://cb.lk/speech"

data = requests.get(link)

with open("modi.txt", "wt" ) as pfile:
    pfile.write(data.text)

speech = data.text


freq = { }
window = 5 

for k in range(window , len(speech)):
    word = speech[k - window : k]
    ch = speech[k]
    if word not in freq :
        freq[word] = {}
    if ch not in freq[word]:
        freq[word][ch] = 0
    freq[word][ch] += 1 

freq
# Out:
# {'26 8 ': {'2': 2},
#  '6 8 2': {'0': 2},
#  ' 8 20': {'1': 17},
#  '8 201': {'6': 3, '5': 9, '4': 3},
#  ' 2016': {',': 51, ';': 2, '.': 14, ' ': 8, '-': 2},
#  '2016,': {' ': 51},
#  '016, ': {'I': 30,
#   'S': 1,
#   'M': 1,
#   'A': 1,
#   'K': 2,
#   'h': 0,
#   'm': 0,
#   'U': 2,
#   'B': 1,
#   'D': 0,
#   'C': 0,
#   'J': 0,
#   't': 0,
#   's': 0},
#  '16, I': {'n': 27, 'r': 2},
#  '6, In': {'d': 28},
#  ', Ind': {'i': 253, 'e': 0, 'u': 4, 'o': 0},
#  ' Indi': {'a': 2901, 'c': 0},
#  'India': {'\n': 88,
#   ' ': 1369,
#   '’': 158,
#   'n': 573,
#   '.': 388,
#   "'": 162,
#   ',': 193,
#   '-': 72,
#   '”': 16,
#   ';': 14,
#   'v': 0,
#   '!': 1,
#   '"': 43,
#   ')': 2,
#   '?': 3,
#   ':': 2,
#   '#': 0,
#   '`': 45},
#  'ndia\n': {'N': 1,
#   'M': 19,
#   'I': 10,
#   'A': 2,
#   'G': 3,
#   'D': 1,
#   'B': 1,
#   'P': 2,
#   'm': 2,
#   'J': 2,
#   's': 0,
#   'c': 0,
#   'f': 1,
#   'H': 2,
#   'U': 0,
#   'p': 0,
#   'Y': 0,
#   'T': 0,
#   'R': 1,
#   'S': 4,
#   'E': 1,
#   'C': 1,
#   'V': 6,
#   'e': 0,
#   'W': 1,
#   'O': 1,
#   'F': 0,
#   'L': 0},
#  'dia\nN': {'i': 0, 'o': 0},
#  'ia\nNi': {'t': 0},
#  'a\nNit': {'i': 0},
#  '\nNiti': {' ': 0},
#  'Niti ': {'A': 2},
#  'iti A': {'a': 0, 'y': 1},
#  'ti Aa': {'y': 0},
#  'i Aay': {'o': 0},
#  ' Aayo': {'g': 3},
#  'Aayog': {'\n': 0, '.': 0, ',': 0, ' ': 0},
#  'ayog\n': {'T': 0},
#  'yog\nT': {'h': 0},
#  'og\nTh': {'e': 0},
#  'g\nThe': {'r': 0},
#  '\nTher': {'e': 82},
#  'There': {' ': 316, 'f': 58, ',': 0, 'b': 1, '`': 0, 'a': 0},
#  'here ': {'w': 209,
#   'c': 31,
#   'i': 340,
#   's': 48,
#   'I': 11,
#   'o': 25,
#   'a': 252,
#   'f': 28,
#   'm': 32,
#   'h': 48,
#   't': 116,
#   'y': 11,
#   'b': 22,
#   'u': 0,
#   'e': 24,
#   'H': 0,
#   'p': 6,
#   'P': 0,
#   'g': 4,
#   'F': 0,
#   '\n': 0,
#   'U': 0,
#   'k': 1,
#   'S': 2,
#   'C': 1,
#   'n': 7,
#   'G': 0,
#   'l': 3,
#   'B': 5,
#   'd': 10,
#   'r': 3,
#   'N': 0,
#   '6': 0,
#   'Y': 0,
#   'q': 0,
#   'T': 0,
#   'L': 0,
#   '5': 1,
#   '4': 0,
#   '–': 0,
#   'j': 0},
#  'ere w': {'a': 75, 'i': 51, 'e': 66, 'o': 12, 'h': 4, 'r': 0},
#  're wa': {'s': 84, 't': 5, 'y': 2, 'g': 0, 'n': 0, 'i': 0},
#  'e was': {' ': 178, '\n': 0, 't': 1, 'h': 0},
#  ' was ': {'a': 181,
#   'b': 27,
#   'c': 28,
#   'L': 1,
#   'h': 13,
#   'i': 50,
#   'm': 16,
#   'o': 30,
#   'y': 5,
#   'l': 21,
#   'w': 13,
#   't': 107,
#   's': 56,
#   'n': 63,
#   'd': 33,
#   'r': 23,
#   'p': 32,
#   'g': 12,
#   'e': 19,
#   'k': 1,
#   'u': 4,
#   '7': 1,
#   'f': 32,
#   'v': 11,
#   'K': 0,
#   'S': 2,
#   'B': 1,
#   '9': 0,
#   'M': 0,
#   '1': 1,
#   '“': 7,
#   'A': 1,
#   'j': 2,
#   'स': 0,
#   'C': 0,
#   'J': 0,
#   'I': 0},
#  'was a': {' ': 106,
#   't': 5,
#   'l': 20,
#   'c': 8,
#   'n': 13,
#   'v': 0,
#   'p': 0,
#   'b': 5,
#   's': 6,
#   'm': 3,
#   'g': 0,
#   'u': 0,
#   'd': 1,
#   'w': 1},
#  'as a ': {'t': 37,
#   'M': 0,
#   'k': 2,
#   'g': 12,
#   'm': 31,
#   's': 47,
#   'f': 14,
#   'c': 21,
#   'r': 17,
#   'w': 13,
#   'v': 15,
#   'y': 1,
#   'p': 35,
#   'l': 19,
#   'P': 5,
#   'n': 17,
#   'b': 12,
#   'N': 0,
#   'q': 0,
#   'S': 2,
#   'd': 14,
#   'h': 8,
#   'j': 2,
#   'B': 1,
#   '‘': 0,
#   'C': 2,
#   'Q': 0,
#   'G': 0},
#  's a t': {'i': 27, 'e': 14, 'a': 2, 'r': 21, 'o': 7, 'h': 2, 'y': 0, 'u': 0},
#  ' a ti': {'m': 66, 'n': 0, 'g': 0},
#  'a tim': {'e': 66},
#  ' time': {' ': 328,
#   ',': 83,
#   '\n': 1,
#   's': 118,
#   '.': 57,
#   'r': 0,
#   '-': 6,
#   'l': 27,
#   '?': 0,
#   'f': 1,
#   'd': 0,
#   ';': 1},
#  'time ': {'w': 62,
#   'n': 12,
#   't': 74,
#   'i': 34,
#   'I': 14,
#   'a': 44,
#   'b': 11,
#   'o': 40,
#   'h': 23,
#   'c': 12,
#   'f': 26,
#   'g': 0,
#   'l': 10,
#   'r': 10,
#   's': 36,
#   'B': 0,
#   'z': 1,
#   'e': 4,
#   'p': 7,
#   'O': 0,
#   'P': 0,
#   'S': 1,
#   'd': 3,
#   'H': 1,
#   'm': 0,
#   'N': 0,
#   'y': 0},
#  'ime w': {'h': 40, 'a': 2, 'e': 8, 'i': 7, 'o': 1},
#  'me wh': {'e': 46, 'i': 3, 'o': 4, 'a': 1, 'y': 0},
#  'e whe': {'n': 60, 'r': 17, 't': 5, 'e': 3},
#  ' when': {' ': 371, 'e': 18, ',': 3},
#  'when ': {'d': 4,
#   'e': 7,
#   'w': 91,
#   'E': 0,
#   'm': 4,
#   'I': 55,
#   't': 87,
#   'G': 2,
#   'a': 14,
#   'p': 6,
#   'g': 4,
#   'b': 0,
#   'i': 13,
#   's': 8,
#   'v': 0,
#   'n': 2,
#   'c': 2,
#   'h': 14,
#   'y': 21,
#   'o': 7,
#   'A': 2,
#   'T': 0,
#   'P': 1,
#   'S': 0,
#   'f': 1,
#   'B': 0,
#   'V': 0},
#  'hen d': {'e': 2, 'i': 0, 'o': 3, 'a': 0, 'r': 0},
#  'en de': {'v': 1,
#   'f': 6,
#   'c': 11,
#   'e': 3,
#   't': 0,
#   's': 3,
#   'd': 0,
#   'm': 0,
#   'l': 0,
#   'r': 0,
#   'p': 0},
#  'n dev': {'e': 35, 'o': 0},
#  ' deve': {'l': 666},
#  'devel': {'o': 674},
#  'evelo': {'p': 756},
#  'velop': {'m': 537,
#   ' ': 75,
#   'i': 85,
#   'e': 47,
#   '\n': 0,
#   's': 2,
#   ',': 2,
#   '.': 2},
#  'elopm': {'e': 537},
#  'lopme': {'n': 537},
#  'opmen': {'t': 537},
#  'pment': {' ': 397,
#   '.': 106,
#   's': 11,
#   "'": 1,
#   'a': 6,
#   ',': 37,
#   ';': 5,
#   '?': 0,
#   '\n': 0},
#  'ment ': {'w': 128,
#   'p': 67,
#   't': 241,
#   'o': 406,
#   'c': 43,
#   'i': 246,
#   's': 47,
#   'e': 21,
#   'f': 95,
#   'a': 260,
#   'r': 20,
#   'S': 4,
#   'h': 93,
#   'm': 33,
#   'u': 10,
#   'l': 15,
#   'B': 19,
#   'P': 7,
#   'g': 10,
#   'A': 16,
#   'd': 21,
#   'b': 39,
#   'F': 11,
#   'T': 5,
#   'n': 9,
#   '-': 1,
#   'G': 14,
#   'C': 7,
#   ' ': 9,
#   'j': 5,
#   '&': 0,
#   '–': 3,
#   'D': 0,
#   'R': 1,
#   'I': 3,
#   'E': 0,
#   'W': 0,
#   'y': 1,
#   'N': 0,
#   '/': 0,
#   'H': 0,
#   'v': 0,
#   '(': 5,
#   'M': 1,
#   'K': 0,
#   'L': 0,
#   'k': 0},
#  'ent w': {'a': 20, 'i': 90, 'o': 22, 'h': 19, 'r': 0, 'e': 11},
#  'nt wa': {'s': 20, 'y': 1, 'r': 0, 'n': 0},
#  't was': {' ': 170, '\n': 0, 't': 2, 'n': 0, ',': 0, '.': 0, 'h': 3},
#  'was b': {'e': 11, 'o': 9, 'u': 2, 'r': 2},
#  'as be': {'l': 1,
#   'e': 319,
#   'c': 40,
#   'i': 9,
#   'g': 5,
#   't': 1,
#   's': 1,
#   'n': 2,
#   ' ': 0,
#   'y': 0},
#  's bel': {'i': 20, 'o': 7},
#  ' beli': {'e': 285, 't': 0},
#  'belie': {'v': 215, 'f': 72},
#  'eliev': {'e': 221, 'i': 3},
#  'lieve': {'d': 22, ' ': 168, ',': 19, 's': 3, 'r': 5},
#  'ieved': {' ': 78, ',': 3, '.': 10, '\n': 0, '?': 0},
#  'eved ': {'t': 17,
#   'i': 23,
#   'b': 6,
#   'w': 4,
#   'a': 7,
#   'f': 0,
#   'm': 3,
#   'n': 0,
#   ' ': 0,
#   's': 2,
#   'e': 1,
#   'o': 1,
#   '1': 0,
#   'y': 0,
#   'q': 0},
#  'ved t': {'o': 17, 'h': 43, 'e': 0, 'a': 0, 'r': 0},
#  'ed to': {' ': 1021,
#   '\n': 0,
#   'g': 7,
#   'd': 20,
#   'o': 1,
#   'w': 10,
#   'p': 0,
#   'u': 0,
#   '.': 0},
#  'd to ': {'d': 60,
#   'r': 67,
#   'i': 55,
#   'y': 9,
#   'j': 8,
#   'w': 54,
#   'a': 83,
#   's': 120,
#   'e': 73,
#   'g': 25,
#   'Y': 2,
#   't': 188,
#   'h': 51,
#   'o': 36,
#   'b': 123,
#   'c': 97,
#   'f': 49,
#   'l': 31,
#   'k': 24,
#   'p': 58,
#   'u': 19,
#   'L': 1,
#   'm': 46,
#   'S': 3,
#   'v': 19,
#   'A': 8,
#   'n': 6,
#   '4': 3,
#   'D': 1,
#   '1': 2,
#   'N': 2,
#   'F': 0,
#   'P': 6,
#   'I': 5,
#   'K': 0,
#   'C': 3,
#   'M': 6,
#   '7': 3,
#   'X': 0,
#   'G': 0,
#   'H': 0,
#   'U': 0,
#   'T': 0,
#   'q': 1,
#   '$': 0},
#  ' to d': {'e': 164, 'o': 138, 'i': 51, 'r': 22, 'a': 4},
#  'to de': {'p': 2,
#   'v': 58,
#   'f': 22,
#   'm': 5,
#   'c': 12,
#   'l': 14,
#   't': 2,
#   'a': 9,
#   'e': 24,
#   's': 7,
#   'n': 1,
#   'd': 5},
#  'o dep': {'e': 0, 'r': 0, 'l': 0, 'a': 0},
#  ' depe': {'n': 32},
#  'depen': {'d': 152},
#  'epend': {' ': 7, 's': 11, 'e': 131, 'a': 0},
#  'pend ': {'o': 7,
#   't': 2,
#   'a': 2,
#   'q': 0,
#   'm': 4,
#   'y': 0,
#   'h': 1,
#   'n': 0,
#   'i': 1,
#   's': 2,
#   '2': 0},
#  'end o': {'n': 6, 'f': 20, 'p': 0, 'u': 8, 'v': 0},
#  'nd on': {' ': 30, 'e': 17, 'l': 6, 'c': 3, '.': 0},
#  'd on ': {'t': 98,
#   '2': 2,
#   'I': 2,
#   'D': 0,
#   'Y': 0,
#   'i': 3,
#   'b': 5,
#   'g': 3,
#   'o': 14,
#   'e': 5,
#   'a': 18,
#   'd': 2,
#   'n': 2,
#   'w': 2,
#   'l': 1,
#   'p': 2,
#   'c': 5,
#   'A': 1,
#   ' ': 0,
#   'S': 2,
#   'F': 1,
#   'm': 5,
#   'r': 2,
#   's': 5,
#   '1': 5,
#   'f': 2,
#   'h': 1,
#   'v': 0,
#   'B': 0,
#   'C': 0,
#   'y': 0,
#   'u': 0,
#   '‘': 0},
#  ' on t': {'h': 590, 'r': 10, 'o': 10, 'e': 8, 'a': 6, 'w': 4, 'i': 8, 'u': 0},
#  'on th': {'e': 561, 'a': 132, 'i': 67, 'r': 16, 'o': 3},
#  'n the': {' ': 2511,
#   'm': 29,
#   's': 50,
#   '\n': 4,
#   'i': 115,
#   'y': 30,
#   'r': 25,
#   'n': 4},
#  ' the ': {'q': 45,
#   'N': 161,
#   'G': 147,
#   'o': 332,
#   'i': 351,
#   'S': 192,
#   'p': 1290,
#   'r': 691,
#   'y': 117,
#   's': 1156,
#   'c': 1092,
#   't': 478,
#   'a': 331,
#   'n': 404,
#   'w': 976,
#   'R': 70,
#   'T': 45,
#   'b': 486,
#   'l': 506,
#   'f': 827,
#   'M': 102,
#   'g': 501,
#   'C': 137,
#   'L': 21,
#   'P': 163,
#   'd': 501,
#   'e': 539,
#   'm': 475,
#   'I': 248,
#   'v': 256,
#   '4': 3,
#   'h': 321,
#   'z': 1,
#   'Y': 6,
#   '3': 10,
#   'u': 93,
#   'K': 16,
#   'A': 120,
#   'j': 38,
#   'H': 40,
#   'V': 10,
#   'U': 152,
#   'B': 68,
#   '1': 59,
#   'W': 77,
#   '‘': 30,
#   '“': 18,
#   'k': 47,
#   'E': 50,
#   '2': 39,
#   'F': 46,
#   'J': 11,
#   'D': 32,
#   '"': 12,
#   'O': 20,
#   '8': 1,
#   ' ': 2,
#   '6': 4,
#   '7': 8,
#   '5': 8,
#   "'": 6,
#   '9': 0,
#   'व': 0,
#   '\n': 1,
#   'Q': 0},
#  'the q': {'u': 45},
#  'he qu': {'a': 29, 'e': 16, 'o': 0, 'i': 0},
#  'e qua': {'n': 3, 'l': 32, 'r': 0},
#  ' quan': {'t': 16},
#  'quant': {'i': 11, 'u': 4},
#  'uanti': {'t': 10, 'f': 0},
#  'antit': {'y': 9, 'i': 0},
#  'ntity': {' ': 26, '.': 2, ',': 2, ';': 0, '?': 0},
#  'tity ': {'o': 11,
#   'h': 0,
#   'a': 5,
#   't': 0,
#   'N': 0,
#   'c': 2,
#   'r': 0,
#   'P': 0,
#   's': 0,
#   'f': 0,
#   'w': 0},
#  'ity o': {'f': 293, 'n': 12, 'r': 6, 'v': 1},
#  'ty of': {' ': 333, '\n': 0, 'f': 0},
#  'y of ': {'c': 19,
#   'i': 14,
#   'g': 14,
#   'y': 33,
#   's': 32,
#   'o': 67,
#   'r': 10,
#   'M': 14,
#   'w': 10,
#   't': 160,
#   'C': 5,
#   'A': 11,
#   'D': 8,
#   'I': 28,
#   '1': 9,
#   'a': 34,
#   'e': 17,
#   'l': 47,
#   'G': 9,
#   'S': 11,
#   'P': 2,
#   '‘': 1,
#   'd': 5,
#   'f': 10,
#   'm': 4,
#   'J': 6,
#   'E': 4,
#   'N': 6,
#   'p': 18,
#   'n': 11,
#   'h': 22,
#   'X': 0,
#   'K': 1,
#   '3': 1,
#   'F': 1,
#   'H': 5,
#   'T': 4,
#   'Y': 12,
#   'L': 4,
#   '2': 1,
#   'u': 8,
#   'B': 4,
#   'य': 0,
#   'V': 2,
#   '“': 0,
#   'k': 2,
#   'R': 2,
#   'b': 5,
#   'v': 2,
#   'U': 0,
#   '5': 0,
#   '"': 0,
#   '8': 0},
#  ' of c': {'a': 29,
#   'h': 43,
#   'o': 244,
#   'i': 11,
#   'r': 39,
#   'e': 6,
#   'l': 63,
#   'u': 12,
#   'y': 3},
#  'of ca': {'p': 6, 'u': 1, 'r': 11, 's': 3, 'l': 1, 'n': 1, 't': 0},
#  'f cap': {'i': 4, 'a': 1},
#  ' capi': {'t': 68},
#  'capit': {'a': 68},
#  'apita': {'l': 66, ' ': 5},
#  'pital': {' ': 53, 'i': 42, '.': 10, 's': 22, '\n': 0, ',': 3, '’': 0},
#  'ital ': {'a': 22,
#   'c': 9,
#   'e': 5,
#   'p': 7,
#   'w': 6,
#   'b': 3,
#   'f': 11,
#   'I': 36,
#   'g': 6,
#   'n': 5,
#   'i': 14,
#   't': 8,
#   'l': 5,
#   'd': 6,
#   'A': 0,
#   'm': 0,
#   'o': 7,
#   's': 2,
#   'T': 0,
#   'k': 0,
#   'r': 2,
#   'h': 0,
#   'D': 1,
#   'C': 0},
#  'tal a': {'n': 21,
#   'c': 2,
#   'g': 8,
#   'm': 1,
#   't': 1,
#   's': 0,
#   'r': 3,
#   ' ': 0,
#   'u': 0},
#  'al an': {'d': 210, 'a': 1, 'g': 1, 'i': 0, 't': 0},
#  'l and': {' ': 332},
#  ' and ': {'l': 133,
#   'i': 540,
#   'p': 486,
#   't': 1222,
#   'e': 482,
#   'f': 285,
#   'w': 358,
#   'a': 562,
#   'o': 314,
#   'u': 84,
#   'k': 19,
#   'S': 178,
#   'C': 86,
#   'M': 63,
#   's': 835,
#   'h': 296,
#   'r': 282,
#   'I': 300,
#   'N': 17,
#   'c': 558,
#   'm': 306,
#   'd': 298,
#   'g': 188,
#   'n': 131,
#   'B': 27,
#   'U': 16,
#   'G': 63,
#   '1': 11,
#   'F': 20,
#   'E': 34,
#   'b': 170,
#   'A': 96,
#   'y': 84,
#   '4': 3,
#   '5': 2,
#   'j': 16,
#   '3': 2,
#   'W': 5,
#   'T': 40,
#   'K': 23,
#   'P': 50,
#   'H': 19,
#   '2': 10,
#   'v': 66,
#   "'": 1,
#   '\n': 3,
#   'L': 13,
#   'D': 29,
#   'q': 16,
#   'J': 7,
#   'R': 22,
#   'V': 10,
#   '8': 1,
#   '‘': 3,
#   'O': 5,
#   '6': 5,
#   '7': 3,
#   '"': 3,
#   'ल': 0,
#   'z': 2,
#   '“': 2,
#   'स': 2,
#   '9': 3,
#   'X': 0,
#   'Y': 4,
#   ' ': 0,
#   'Q': 1},
#  'and l': {'a': 31, 'i': 33, 'o': 29, 'e': 41, 'u': 0},
#  'nd la': {'b': 3,
#   'u': 5,
#   's': 2,
#   'k': 2,
#   'r': 5,
#   'n': 6,
#   't': 1,
#   'c': 0,
#   'w': 3,
#   'i': 0,
#   'y': 0},
#  'd lab': {'o': 5, 's': 1},
#  ' labo': {'u': 48, 'r': 10},
#  'labou': {'r': 48},
#  'abour': {'.': 1, ' ': 25, 'e': 25, ',': 0},
#  'bour.': {' ': 4, '\n': 0},
#  'our. ': {'T': 3, '\n': 6, 'I': 3, 'P': 0, 'B': 1, 'W': 1, 'O': 0, 'D': 0},
#  'ur. T': {'o': 0, 'h': 8},
#  'r. To': {'d': 5, ' ': 2, 'o': 0, 'g': 0},
#  '. Tod': {'a': 118},
#  ' Toda': {'y': 128},
#  'Today': {' ': 69, ',': 182, "'": 2, '’': 1},
#  'oday ': {'w': 27,
#   'l': 0,
#   'I': 40,
#   'b': 4,
#   't': 36,
#   'o': 14,
#   'i': 44,
#   'f': 4,
#   'm': 3,
#   'p': 2,
#   'h': 4,
#   'a': 25,
#   '–': 1,
#   'c': 1,
#   'S': 0,
#   'g': 2,
#   'r': 1,
#   's': 2,
#   'n': 2,
#   'y': 1,
#   'e': 0,
#   'A': 0,
#   '-': 0,
#   'P': 0,
#   'N': 0,
#   'd': 0,
#   ' ': 0,
#   'G': 0},
#  'day w': {'e': 15, 'h': 16, 'a': 2, 'i': 6},
#  'ay we': {' ': 32, 'r': 1, 'l': 0},
#  'y we ': {'k': 1,
#   'a': 19,
#   'h': 19,
#   'c': 5,
#   't': 2,
#   'l': 3,
#   'g': 2,
#   'w': 13,
#   'm': 2,
#   'v': 0,
#   'i': 0,
#   'b': 1,
#   'f': 2,
#   's': 6,
#   'd': 0,
#   'p': 0,
#   'u': 0,
#   'r': 0,
#   'o': 0},
#  ' we k': {'n': 20, 'e': 4, 'i': 0},
#  'we kn': {'o': 20},
#  'e kno': {'w': 66},
#  ' know': {' ': 211,
#   ',': 15,
#   'l': 86,
#   'n': 45,
#   's': 17,
#   'i': 3,
#   '.': 3,
#   '-': 0},
#  'know ': {'t': 116,
#   'w': 17,
#   'h': 18,
#   'a': 18,
#   'y': 6,
#   'f': 1,
#   'C': 0,
#   'o': 7,
#   'e': 1,
#   'S': 0,
#   'i': 9,
#   'b': 0,
#   'm': 1,
#   'v': 0,
#   'r': 0,
#   '-': 0,
#   's': 1,
#   'I': 1,
#   'p': 0},
#  'now t': {'h': 129, 'i': 1, 'u': 6, 'o': 6, 'r': 1},
#  'ow th': {'a': 116, 'e': 81, 'i': 11, 'o': 2},
#  'w tha': {'t': 125},
#  ' that': {' ': 3260,
#   ',': 44,
#   '.': 38,
#   '\n': 0,
#   ':': 3,
#   'I': 0,
#   '’': 4,
#   '?': 2,
#   'M': 0,
#   '"': 0,
#   '!': 0,
#   '-': 0,
#   "'": 1},
#  'that ': {'i': 336,
#   'g': 30,
#   'e': 89,
#   'w': 452,
#   'I': 191,
#   'G': 7,
#   'o': 176,
#   'a': 186,
#   'p': 89,
#   'm': 77,
#   'r': 31,
#   'h': 132,
#   't': 666,
#   'l': 37,
#   'b': 44,
#   'n': 50,
#   'y': 120,
#   'Y': 4,
#   'd': 82,
#   'D': 4,
#   's': 113,
#   'f': 39,
#   'c': 99,
#   'C': 5,
#   'j': 8,
#   'P': 11,
#   'K': 3,
#   '1': 6,
#   'u': 15,
#   'M': 12,
#   'k': 4,
#   'F': 1,
#   'N': 5,
#   'L': 1,
#   'S': 15,
#   'v': 9,
#   '“': 6,
#   "'": 0,
#   'B': 5,
#   'U': 1,
#   'q': 1,
#   '-': 1,
#   '5': 1,
#   ' ': 13,
#   'Q': 1,
#   '3': 2,
#   'J': 2,
#   '‘': 1,
#   '6': 0,
#   '–': 0,
#   'A': 15,
#   '2': 1,
#   'E': 1,
#   '•': 0,
#   '7': 0,
#   'H': 1,
#   'T': 1,
#   'R': 2,
#   'V': 1,
#   '"': 0},
#  'hat i': {'t': 95, 's': 257, 'n': 65, 'f': 51, 'm': 5, 'd': 0},
#  'at it': {' ': 95, 's': 6, '.': 1, ',': 0},
#  't it ': {'d': 4,
#   'i': 62,
#   'c': 9,
#   'w': 32,
#   's': 5,
#   'p': 0,
#   'b': 3,
#   'f': 4,
#   't': 6,
#   'm': 5,
#   'a': 9,
#   'h': 9,
#   'e': 0,
#   'o': 4,
#   'g': 2,
#   'l': 0,
#   'n': 4},
#  ' it d': {'e': 3, 'o': 7, 'i': 6, 'r': 0, 'u': 0},
#  'it de': {'p': 1, 'e': 0, 'm': 0, 'a': 0},
#  't dep': {'e': 2, 'r': 0, 'o': 0, 'l': 0, 'a': 3},
#  'pends': {' ': 12},
#  'ends ': {'a': 23,
#   'o': 15,
#   'm': 3,
#   't': 8,
#   'f': 15,
#   'l': 1,
#   'i': 9,
#   '!': 0,
#   'n': 0,
#   'w': 5,
#   's': 1,
#   'h': 1,
#   'b': 1,
#   'I': 1,
#   'r': 0,
#   'e': 1,
#   'g': 0},
#  'nds a': {'s': 0, ' ': 2, 'n': 40, 'r': 13, 'l': 1, 't': 2, 'b': 0, 'c': 0},
#  'ds as': {' ': 2},
#  's as ': {'m': 7,
#   'a': 39,
#   'h': 1,
#   'c': 4,
#   'w': 26,
#   'o': 6,
#   'i': 15,
#   's': 5,
#   'p': 7,
#   'd': 1,
#   'l': 0,
#   'e': 0,
#   't': 18,
#   'r': 1,
#   'g': 0,
#   'P': 0,
#   'N': 0,
#   'L': 0,
#   'I': 0,
#   'y': 0,
#   'b': 0,
#   '“': 0},
#  ' as m': {'u': 20, 'e': 2, 'y': 5, 'o': 2, 'a': 6, 'i': 0},
#  'as mu': {'c': 23, 'l': 2},
#  's muc': {'h': 46},
#  ' much': {' ': 154, '.': 27, ',': 5, '!': 2, '?': 0},
#  'much ': {'o': 14,
#   't': 26,
#   'l': 6,
#   'a': 22,
#   'w': 0,
#   'b': 11,
#   'm': 18,
#   'c': 5,
#   'g': 2,
#   'h': 7,
#   'p': 5,
#   'e': 5,
#   'd': 3,
#   'f': 8,
#   'u': 0,
#   'n': 1,
#   'C': 0,
#   's': 2,
#   'I': 1},
#  'uch o': {'n': 1, 'f': 17, 't': 0, 'b': 0, 'r': 0, 'l': 0, 'p': 0},
#  'ch on': {' ': 10, 'e': 16, 'c': 0},
#  'h on ': {'t': 5,
#   'd': 0,
#   'a': 0,
#   'i': 0,
#   '1': 2,
#   'D': 0,
#   's': 0,
#   'o': 0,
#   'T': 0},
#  ' qual': {'i': 83},
#  'quali': {'t': 98, 'f': 4},
#  'ualit': {'y': 91, 'i': 4, 'a': 5},
#  'ality': {' ': 126, '.': 49, ',': 20, ';': 6, '—': 0, '”': 0, '?': 0},
#  'lity ': {'o': 126,
#   'a': 79,
#   't': 89,
#   'b': 6,
#   's': 4,
#   'f': 24,
#   'i': 57,
#   'h': 3,
#   'm': 6,
#   ' ': 0,
#   'r': 2,
#   'R': 1,
#   'l': 0,
#   'w': 7,
#   'g': 0,
#   'c': 3,
#   'p': 1,
#   'A': 0,
#   '–': 1,
#   '=': 0,
#   'H': 1,
#   'e': 4},
#  ' of i': {'n': 175, 't': 102, 'l': 3, 'r': 0, 'm': 22, 'd': 11, 's': 10},
#  'of in': {'s': 15,
#   'd': 32,
#   't': 46,
#   'j': 0,
#   'v': 22,
#   'f': 25,
#   'n': 8,
#   'p': 5,
#   'c': 7,
#   'a': 1,
#   'l': 0,
#   'h': 0,
#   ' ': 3},
#  'f ins': {'t': 7, 'p': 6, 'u': 0},
#  ' inst': {'i': 166, 'r': 37, 'e': 13, 'a': 27},
#  'insti': {'t': 145, 'g': 1, 'l': 9, 'n': 8},
#  'nstit': {'u': 241},
#  'stitu': {'t': 233, 'e': 9},
#  'titut': {'i': 193, 'e': 39},
#  'ituti': {'o': 191, 'n': 1},
#  'tutio': {'n': 191},
#  'ution': {'s': 146,
#   ' ': 182,
#   '.': 52,
#   'a': 23,
#   ',': 16,
#   ':': 1,
#   '\n': 0,
#   ';': 2,
#   '?': 1,
#   'i': 1},
#  'tions': {' ': 889,
#   '.': 300,
#   'h': 209,
#   ',': 131,
#   '\n': 5,
#   ':': 1,
#   ';': 13,
#   '”': 1,
#   '?': 2,
#   "'": 0,
#   '-': 0,
#   '`': 0},
#  'ions ': {'a': 230,
#   'i': 90,
#   'w': 92,
#   't': 146,
#   'o': 225,
#   'n': 3,
#   'O': 0,
#   'h': 45,
#   'f': 68,
#   'g': 5,
#   'c': 22,
#   's': 20,
#   'b': 32,
#   'r': 10,
#   'u': 0,
#   'l': 14,
#   'm': 14,
#   'D': 0,
#   '(': 0,
#   'q': 2,
#   'k': 1,
#   ' ': 8,
#   'P': 2,
#   '-': 1,
#   'S': 11,
#   'p': 5,
#   '—': 0,
#   'd': 9,
#   'C': 3,
#   'e': 2,
#   '–': 2,
#   'y': 1,
#   'v': 1,
#   'G': 1,
#   '\n': 0,
#   'A': 0,
#   'I': 1,
#   'R': 0,
#   'T': 0},
#  'ons a': {'n': 148,
#   'r': 60,
#   't': 3,
#   'g': 4,
#   'd': 1,
#   'h': 0,
#   's': 12,
#   'b': 3,
#   'm': 0,
#   'c': 2,
#   'l': 1,
#   'f': 0,
#   'v': 1,
#   ' ': 0},
#  'ns an': {'d': 217, ' ': 1},
#  's and': {' ': 2114, '\n': 1, ',': 3},
#  'and i': {'d': 7,
#   'n': 366,
#   't': 104,
#   's': 36,
#   'f': 24,
#   'm': 27,
#   'r': 6,
#   'l': 0},
#  'nd id': {'e': 7},
#  'd ide': {'a': 11, 'n': 2, 'o': 0},
#  ' idea': {'s': 62, ' ': 35, 'l': 31, '.': 6, ',': 2},
#  'ideas': {'.': 4, ' ': 49, ',': 6, '…': 0},
#  'deas.': {' ': 3, '\n': 0},
#  'eas. ': {'E': 0,
#   'T': 4,
#   'W': 8,
#   '\n': 13,
#   ' ': 1,
#   'B': 0,
#   'I': 1,
#   'U': 0,
#   'P': 0,
#   'A': 0,
#   'G': 0,
#   'N': 0},
#  'as. E': {'a': 0},
#  's. Ea': {'r': 1, 'c': 2},
#  '. Ear': {'l': 11},
#  ' Earl': {'y': 1, 'i': 10},
#  'Early': {' ': 1},
#  'arly ': {'l': 1,
#   'f': 4,
#   'p': 1,
#   't': 18,
#   '3': 1,
#   'b': 3,
#   'w': 9,
#   '1': 11,
#   'a': 19,
#   'c': 11,
#   'g': 1,
#   'r': 1,
#   'e': 1,
#   '5': 2,
#   '7': 3,
#   'k': 5,
#   'd': 7,
#   'o': 7,
#   'R': 1,
#   '9': 0,
#   'i': 14,
#   'h': 3,
#   '8': 2,
#   'm': 0,
#   'I': 0,
#   '2': 7,
#   's': 4,
#   'n': 2,
#   'W': 0,
#   'v': 0,
#   '6': 3,
#   '4': 1,
#   'y': 1},
#  'rly l': {'a': 0, 'o': 3, 'i': 0},
#  'ly la': {'s': 2, 't': 0, 'r': 0, 'u': 4, 'y': 0},
#  'y las': {'t': 11},
#  ' last': {' ': 207, 'i': 12, '\n': 0, 'e': 0, '.': 0, ',': 0},
#  'last ': {'y': 40,
#   't': 26,
#   'w': 3,
#   'c': 7,
#   'J': 0,
#   'o': 4,
#   '2': 1,
#   '6': 3,
#   'm': 25,
#   'h': 2,
#   'f': 25,
#   's': 4,
#   'r': 2,
#   'e': 7,
#   'S': 8,
#   '1': 6,
#   'l': 1,
#   'n': 3,
#   'p': 2,
#   'a': 3,
#   'v': 2,
#   '7': 0,
#   '5': 1,
#   '8': 0,
#   'd': 1,
#   'N': 0,
#   'g': 0,
#   'b': 0,
#   'L': 0,
#   'D': 0,
#   '3': 0,
#   'P': 0},
#  'ast y': {'e': 60, 'o': 1},
#  'st ye': {'a': 66, 't': 0},
#  't yea': {'r': 97},
#  ' year': {',': 70,
#   's': 370,
#   ' ': 157,
#   '?': 2,
#   '.': 70,
#   '’': 7,
#   "'": 1,
#   ';': 3,
#   '-': 0,
#   'd': 0,
#   'n': 2,
#   '!': 0,
#   'l': 0},
#  'year,': {' ': 70},
#  'ear, ': {'a': 4,
#   'i': 4,
#   'w': 22,
#   'y': 0,
#   't': 10,
#   's': 1,
#   'b': 0,
#   'p': 2,
#   'M': 0,
#   '9': 0,
#   'o': 3,
#   'I': 9,
#   'm': 0,
#   'e': 0,
#   'h': 0,
#   'c': 3,
#   'f': 0,
#   'd': 1,
#   'j': 0},
#  'ar, a': {' ': 1, 'n': 4, 's': 0, 'l': 0},
#  'r, a ': {'n': 0,
#   'd': 0,
#   'w': 0,
#   'p': 2,
#   'D': 0,
#   's': 1,
#   'f': 1,
#   'g': 0,
#   'b': 0,
#   'c': 0},
#  ', a n': {'e': 13, 'u': 1, 'a': 6},
#  ' a ne': {'w': 241, 't': 8, 'e': 14, 'c': 2, 'o': 0, 'g': 2, 'i': 3, 'a': 1},
#  'a new': {' ': 235, 's': 2, 'l': 0, 'b': 0, ',': 0},
#  ' new ': {'i': 38,
#   't': 25,
#   'n': 6,
#   's': 41,
#   'l': 41,
#   'h': 42,
#   'g': 22,
#   'r': 24,
#   'p': 46,
#   'f': 27,
#   'e': 49,
#   'w': 19,
#   'm': 17,
#   'd': 38,
#   'j': 9,
#   'v': 9,
#   'c': 39,
#   'b': 33,
#   'B': 1,
#   'o': 20,
#   'I': 6,
#   'a': 27,
#   'M': 4,
#   ' ': 1,
#   'A': 3,
#   'y': 3,
#   'u': 4,
#   'P': 2,
#   'z': 0,
#   'S': 1,
#   'N': 0,
#   'E': 0,
#   'k': 0,
#   'L': 0,
#   'R': 1,
#   'C': 1,
#   'J': 0,
#   'G': 1},
#  'new i': {'n': 25, 'd': 12},
#  'ew in': {'s': 7,
#   'd': 2,
#   't': 2,
#   'f': 1,
#   'i': 5,
#   ' ': 5,
#   'c': 1,
#   'n': 2,
#   'q': 0},
#  'w ins': {'t': 8, 'u': 0, 'p': 0},
#  'tion ': {'w': 167,
#   'f': 165,
#   'c': 49,
#   'h': 61,
#   'i': 385,
#   'o': 690,
#   'a': 439,
#   'r': 21,
#   't': 347,
#   'b': 85,
#   's': 73,
#   '-': 4,
#   'd': 16,
#   'm': 28,
#   'p': 34,
#   'T': 16,
#   'v': 1,
#   'y': 4,
#   'l': 13,
#   'S': 5,
#   'P': 7,
#   'A': 15,
#   'n': 9,
#   'e': 13,
#   'g': 13,
#   '–': 7,
#   'B': 2,
#   '\n': 1,
#   'I': 9,
#   ' ': 24,
#   'M': 4,
#   'u': 6,
#   '(': 3,
#   'C': 6,
#   'O': 4,
#   '.': 2,
#   'R': 0,
#   '&': 1,
#   'q': 0,
#   'Y': 0,
#   'D': 0,
#   '+': 0,
#   '=': 0,
#   'F': 0,
#   'H': 0,
#   '"': 0},
#  'ion w': {'a': 33, 'i': 129, 'h': 27, 'o': 8, 'e': 11},
#  'on wa': {'s': 31, 't': 3, 'n': 2, 'r': 1, 'g': 0, 'y': 0},
#  'n was': {' ': 40, ',': 1, 't': 1},
#  'was c': {'r': 3, 'e': 3, 'l': 3, 'a': 2, 'o': 13, 'h': 0},
#  'as cr': {'e': 14, 'o': 1, 'a': 0},
#  's cre': {'a': 36, 'd': 1, 'e': 0},
#  ' crea': {'t': 311},
#  'creat': {'e': 202, 'i': 102, 'o': 6},
#  'reate': {'d': 78, 's': 39, ' ': 126, 'r': 51, 'n': 10},
#  'eated': {',': 1, ' ': 77, '.': 8, 'l': 3},
#  'ated,': {' ': 16},
#  'ted, ': {'n': 0,
#   '“': 0,
#   'w': 5,
#   't': 10,
#   'i': 5,
#   'b': 5,
#   'y': 0,
#   'o': 2,
#   'h': 6,
#   'e': 1,
#   'N': 0,
#   'm': 0,
#   'g': 1,
#   'p': 0,
#   'a': 4,
#   'd': 0,
#   's': 0},
#  'ed, n': {'a': 0, 'o': 0},
#  'd, na': {'m': 0, 't': 0},
#  ', nam': {'e': 2},
#  ' name': {'l': 4, 's': 19, ' ': 47, 'd': 14, '.': 1, ',': 1},
#  'namel': {'y': 3, 'e': 0},
#  'amely': {',': 1, ' ': 2},
#  'mely,': {' ': 1},
#  'ely, ': {'t': 6,
#   'i': 2,
#   'f': 0,
#   'w': 2,
#   'b': 0,
#   'I': 1,
#   'o': 2,
#   's': 0,
#   'y': 1,
#   ' ': 0,
#   'D': 0},
#  'ly, t': {'h': 47, 'i': 0, 'o': 1, 'e': 1},
#  'y, th': {'e': 121, 'a': 9, 'i': 18, 'r': 2, 'o': 1},
#  ', the': {' ': 720,
#   'r': 166,
#   'i': 24,
#   's': 20,
#   'y': 113,
#   'n': 104,
#   '\n': 3,
#   'a': 0},
#  'the N': {'a': 54, 'u': 0, 'o': 90, 'e': 10, 'H': 0, 'I': 0, 'S': 0, 'D': 0},
#  'he Na': {'t': 30, 'i': 0, 'l': 2, 'r': 1, 'g': 17, 'v': 7, 'z': 0},
#  'e Nat': {'i': 35, 'u': 1, 'h': 0},
#  ' Nati': {'o': 166},
#  'Natio': {'n': 174},
#  'ation': {'a': 496,
#   '.': 433,
#   ' ': 1757,
#   's': 1059,
#   ',': 238,
#   '’': 28,
#   ';': 27,
#   '\n': 7,
#   'w': 2,
#   '?': 6,
#   '-': 2,
#   'i': 0,
#   "'": 15,
#   '”': 1,
#   'h': 0,
#   ':': 3,
#   '`': 0,
#   ')': 0},
#  'tiona': {'l': 642, 'r': 2, 't': 0, 'b': 0},
#  'ional': {' ': 685, ',': 4, 's': 22, '\n': 0, 'i': 30, 'l': 13, '.': 5},
#  'onal ': {'I': 15,
#   'a': 56,
#   'e': 42,
#   'i': 36,
#   'S': 21,
#   'c': 69,
#   'D': 16,
#   'Y': 14,
#   'p': 58,
#   'd': 16,
#   's': 39,
#   'l': 33,
#   'g': 5,
#   'f': 43,
#   'r': 30,
#   'R': 4,
#   'w': 4,
#   'n': 6,
#   'C': 25,
#   'H': 9,
#   'M': 6,
#   'A': 10,
#   'm': 28,
#   'T': 9,
#   'b': 12,
#   '2': 0,
#   't': 20,
#   ' ': 0,
#   '0': 0,
#   'O': 1,
#   'F': 10,
#   'B': 1,
#   'h': 5,
#   'v': 3,
#   '1': 1,
#   'N': 10,
#   'W': 9,
#   'G': 0,
#   'P': 2,
#   'u': 1,
#   'k': 7,
#   'U': 0,
#   'o': 3,
#   'j': 0,
#   'K': 0,
#   'L': 2},
#  'nal I': {'n': 11, 'P': 2, 'd': 0},
#  'al In': {'s': 3, 'd': 49, 'v': 6, 'c': 1, 'n': 1, 'f': 0},
#  'l Ins': {'t': 3},
#  ' Inst': {'i': 14, 'e': 2, 'a': 4},
#  'Insti': {'t': 15},
#  'ion f': {'o': 153, 'r': 55, 'a': 1, 'e': 0, 'u': 0},
#  'on fo': {'r': 175, 'o': 8, 's': 5, 'l': 0, 'u': 0},
#  'n for': {' ': 258, 't': 2, 'w': 14, 'e': 7, 'g': 4, 'u': 1, 'c': 3, 'm': 5},
#  ' for ': {'T': 11,
#   'b': 52,
#   'i': 137,
#   'g': 62,
#   'I': 132,
#   'E': 5,
#   'h': 99,
#   'y': 113,
#   't': 890,
#   'o': 205,
#   'S': 26,
#   'a': 313,
#   'p': 83,
#   '2': 13,
#   'Y': 0,
#   'd': 66,
#   'D': 4,
#   'm': 130,
#   'f': 40,
#   's': 126,
#   'e': 136,
#   'w': 42,
#   'A': 31,
#   'c': 138,
#   'C': 15,
#   'r': 61,
#   'l': 30,
#   '3': 4,
#   'v': 4,
#   'u': 68,
#   'F': 16,
#   'M': 19,
#   'K': 6,
#   '"': 1,
#   'P': 9,
#   'n': 35,
#   'R': 7,
#   'H': 2,
#   'O': 0,
#   'G': 8,
#   'B': 8,
#   'U': 4,
#   ' ': 1,
#   '1': 17,
#   '‘': 2,
#   '“': 2,
#   'N': 7,
#   '9': 0,
#   'j': 8,
#   '7': 0,
#   'k': 2,
#   'W': 0,
#   '–': 0,
#   'q': 2,
#   'V': 4,
#   '4': 2,
#   '6': 0,
#   'Z': 0,
#   '5': 1},
#  'for T': {'r': 6, 'e': 0, 'a': 1, 'u': 0, 'B': 0},
#  'or Tr': {'a': 4, 'i': 1},
#  'r Tra': {'n': 2, 'd': 3, 'i': 0},
#  ' Tran': {'s': 36},
#  'Trans': {'f': 15, ' ': 3, 'p': 13, 'i': 3},
#  'ransf': {'o': 155, 'e': 33},
#  'ansfo': {'r': 155},
#  'nsfor': {'m': 155},
#  'sform': {'i': 19,
#   'a': 62,
#   'e': 20,
#   '.': 5,
#   ' ': 39,
#   '”': 2,
#   ',': 0,
#   '’': 0,
#   's': 0},
#  'formi': {'n': 36, 'd': 3},
#  'ormin': {'g': 37},
#  'rming': {' ': 59, '.': 5, ',': 2},
#  'ming ': {'I': 5,
#   's': 9,
#   'f': 4,
#   'm': 7,
#   'P': 4,
#   'g': 12,
#   't': 57,
#   'w': 6,
#   'o': 17,
#   'b': 3,
#   'p': 2,
#   'd': 28,
#   'a': 17,
#   'c': 7,
#   'u': 7,
#   'y': 16,
#   'r': 1,
#   'i': 9,
#   'h': 8,
#   'H': 0,
#   'l': 1,
#   'e': 1,
#   'S': 0,
#   'E': 0},
#  'ing I': {'n': 52, ' ': 8, 'N': 0, '-': 0, 'r': 0},
#  'ng In': {'d': 57, 's': 2, 't': 0, 'c': 0, 'f': 2, 'n': 0},
#  'g Ind': {'i': 56, 'e': 0},
#  'ndia ': {'o': 29,
#   'a': 361,
#   'w': 155,
#   'i': 232,
#   'c': 62,
#   'L': 0,
#   'h': 157,
#   'r': 8,
#   'f': 28,
#   't': 74,
#   'F': 2,
#   's': 49,
#   'l': 9,
#   'b': 24,
#   'K': 0,
#   'e': 9,
#   'p': 20,
#   'A': 6,
#   'm': 12,
#   '–': 10,
#   'C': 12,
#   'g': 4,
#   'S': 11,
#   'I': 6,
#   'B': 2,
#   'd': 9,
#   '\n': 1,
#   '-': 1,
#   ' ': 9,
#   'G': 3,
#   'U': 1,
#   'D': 1,
#   'n': 8,
#   'v': 1,
#   'N': 0,
#   'P': 1,
#   'k': 2,
#   'R': 0,
#   'W': 0,
#   'y': 1,
#   'u': 3,
#   'M': 2,
#   'T': 1,
#   'j': 2,
#   '2': 0},
#  'dia o': {'r': 7, 'v': 3, 'p': 0, 'f': 8, 'w': 0, 'n': 10},
#  'ia or': {' ': 6, 'i': 0},
#  'a or ': {'N': 0,
#   'M': 0,
#   'm': 0,
#   'a': 1,
#   'A': 0,
#   'd': 0,
#   'n': 1,
#   'K': 0,
#   't': 1,
#   'C': 0,
#   'i': 0,
#   'o': 0,
#   'S': 0,
#   'w': 0,
#   'e': 0},
#  ' or N': {'I': 1, 'D': 0},
#  'or NI': {'T': 1},
#  'r NIT': {'I': 1},
#  ' NITI': {'.': 2, ' ': 4, '’': 0},
#  'NITI.': {' ': 2},
#  'ITI. ': {'N': 0, ' ': 1},
#  'TI. N': {'I': 0},
#  'I. NI': {'T': 0},
#  '. NIT': {'I': 0},
#  'NITI ': {'w': 0, ' ': 0, 'A': 3},
#  'ITI w': {'a': 0},
#  'TI wa': {'s': 0},
#  'I was': {' ': 84, 'n': 0},
#  'ated ': {'a': 82,
#   'i': 50,
#   't': 126,
#   'b': 22,
#   'w': 44,
#   'S': 2,
#   'p': 12,
#   'd': 11,
#   'o': 16,
#   'r': 8,
#   'n': 4,
#   'B': 1,
#   'e': 11,
#   's': 15,
#   'f': 17,
#   ' ': 0,
#   'q': 0,
#   'm': 5,
#   'h': 7,
#   ',': 0,
#   'c': 1,
#   'C': 1,
#   'I': 2,
#   'g': 2,
#   '“': 1,
#   '‘': 0,
#   'A': 0,
#   'E': 0,
#   'u': 1,
#   'M': 2,
#   'v': 0,
#   'G': 0,
#   'l': 0},
#  'ted a': {'s': 16,
#   't': 23,
#   'n': 61,
#   'f': 2,
#   'd': 2,
#   'l': 8,
#   ' ': 67,
#   'b': 6,
#   'p': 2,
#   'g': 3,
#   'c': 2,
#   'r': 1,
#   'm': 2,
#   'w': 0},
#  'ed as': {' ': 83, 's': 1, 'p': 7, 'k': 1},
#  'd as ': {'a': 30,
#   't': 23,
#   'c': 1,
#   'm': 7,
#   'p': 2,
#   'M': 1,
#   'o': 9,
#   'I': 3,
#   'd': 1,
#   's': 6,
#   'F': 1,
#   'w': 5,
#   '“': 2,
#   'h': 1,
#   'i': 5,
#   '"': 0,
#   "'": 0,
#   'K': 0,
#   'f': 0,
#   '‘': 1,
#   'q': 0,
#   'n': 0,
#   'g': 0,
#   'L': 0,
#   'N': 0,
#   'y': 2,
#   'W': 0},
#  ' as a': {'n': 35,
#   ' ': 195,
#   'c': 2,
#   'd': 2,
#   'l': 7,
#   'u': 1,
#   't': 0,
#   'r': 1,
#   'p': 0},
#  'as an': {' ': 49, 'd': 34, 'o': 1, 'c': 2, 'n': 2, 'y': 1},
#  's an ': {'e': 52,
#   'o': 23,
#   'I': 4,
#   'i': 78,
#   'a': 30,
#   'h': 1,
#   'u': 5,
#   'E': 0,
#   'M': 0,
#   'A': 2},
#  ' an e': {'v': 6,
#   'x': 62,
#   's': 12,
#   'n': 77,
#   'm': 8,
#   'r': 3,
#   'a': 18,
#   'c': 13,
#   'M': 0,
#   'l': 9,
#   'f': 16,
#   't': 1,
#   'p': 1,
#   'y': 0,
#   'q': 4,
#   'g': 0,
#   '-': 1},
#  'an ev': {'i': 1, 'e': 18},
#  'n evi': {'d': 1, 'l': 0},
#  ' evid': {'e': 15},
#  'evide': {'n': 15},
#  'viden': {'c': 6, 'd': 5, 't': 10},
#  'idenc': {'e': 112, 'y': 3},
#  'dence': {' ': 129, ',': 29, '.': 41, ';': 5},
#  'ence ': {'b': 20,
#   'o': 106,
#   'a': 148,
#   't': 76,
#   'e': 20,
#   'n': 3,
#   'd': 6,
#   'f': 27,
#   'c': 18,
#   'i': 110,
#   'D': 12,
#   'w': 40,
#   'h': 18,
#   'r': 6,
#   'p': 18,
#   ' ': 3,
#   'm': 16,
#   'g': 1,
#   'l': 1,
#   's': 18,
#   '—': 0,
#   'u': 2,
#   'S': 2,
#   'I': 9,
#   'M': 0,
#   'C': 4,
#   'R': 1,
#   '"': 0,
#   'U': 0,
#   'B': 0,
#   'L': 0,
#   'k': 0},
#  'nce b': {'a': 5, 'e': 24, 'y': 4, 'u': 8, 'r': 0},
#  'ce ba': {'s': 2, 'n': 2, 'r': 1},
#  'e bas': {'e': 12, 'i': 48, 'k': 0},
#  ' base': {'d': 48, ' ': 11, ',': 1, '.': 0, ';': 0},
#  'based': {' ': 65, '.': 0, ',': 0},
#  'ased ': {'t': 96,
#   'i': 10,
#   'a': 5,
#   'f': 5,
#   'o': 39,
#   'c': 5,
#   'w': 12,
#   'R': 0,
#   's': 2,
#   'p': 3,
#   'e': 5,
#   'g': 2,
#   'l': 1,
#   'b': 6,
#   ' ': 0,
#   'n': 2,
#   'd': 0,
#   'r': 2,
#   'j': 0,
#   'S': 0,
#   'm': 3,
#   'C': 0,
#   'T': 0,
#   'F': 0,
#   'A': 0},
#  'sed t': {'h': 116, 'o': 165, 'a': 1, 'r': 3, 'i': 0},
#  'ed th': {'i': 73, 'e': 534, 'a': 218, 'r': 44, 'o': 9},
#  'd thi': {'n': 28, 's': 189, 'r': 4},
#  ' thin': {'k': 197, 'g': 192, ';': 0},
#  'think': {' ': 128, 'i': 43, ',': 7, '.': 0, 'e': 6, '…': 0, 's': 9},
#  'hink ': {'t': 31,
#   'a': 18,
#   'd': 0,
#   'g': 2,
#   'o': 35,
#   'e': 2,
#   'b': 4,
#   's': 2,
#   'f': 0,
#   'i': 12,
#   'l': 1,
#   'w': 9,
#   'O': 0,
#   'h': 3,
#   'p': 0},
#  'ink t': {'a': 0, 'o': 4, 'h': 29, 'e': 0},
#  'nk ta': {'n': 0},
#  'k tan': {'k': 0},
#  ' tank': {' ': 4, 'e': 1},
#  'tank ': {'t': 0, 'w': 1, 'i': 0, 'a': 0},
#  'ank t': {'o': 5, 'h': 11},
#  'nk to': {' ': 9, 'g': 0},
#  'k to ': {'g': 0,
#   't': 34,
#   'h': 2,
#   'y': 11,
#   'k': 0,
#   'l': 0,
#   'f': 5,
#   's': 7,
#   'H': 0,
#   'e': 6,
#   'a': 4,
#   'c': 6,
#   'o': 1,
#   'd': 2,
#   'u': 1,
#   'p': 0,
#   'r': 3,
#   'm': 4,
#   'I': 1,
#   'i': 0,
#   'j': 0,
#   'b': 1,
#   'v': 0},
#  ' to g': {'u': 5, 'l': 8, 'i': 58, 'e': 53, 'a': 7, 'o': 63, 'r': 18},
#  'to gu': {'i': 3, 'n': 0, 'w': 0},
#  'o gui': {'d': 5},
#  ' guid': {'e': 28, 'i': 12, 'a': 10},
#  'guide': {' ': 14, 'd': 7, 'l': 5, 's': 1},
#  'uide ': {'I': 0, 'b': 0, 't': 3, 'a': 1, 'u': 0, 'o': 1, 'f': 0, 'y': 2},
#  'ide I': {'n': 4},
#  'de In': {'d': 6},
#  'e Ind': {'i': 316, 'o': 5, 'e': 6, 'u': 3},
#  'ndia’': {'s': 139, ' ': 12, '.': 4, ',': 0},
#  'dia’s': {' ': 139},
#  'ia’s ': {'t': 5,
#   'p': 12,
#   'e': 8,
#   'c': 12,
#   'a': 2,
#   'r': 7,
#   'h': 16,
#   'f': 10,
#   'm': 6,
#   'd': 12,
#   'C': 2,
#   's': 9,
#   'S': 0,
#   'i': 6,
#   'b': 2,
#   'l': 2,
#   'G': 0,
#   'o': 2,
#   'u': 3,
#   'n': 2,
#   'g': 2,
#   'P': 0,
#   'E': 0,
#   'y': 2,
#   '1': 0,
#   'q': 0,
#   'N': 0,
#   'L': 0,
#   'U': 0,
#   'v': 0},
#  'a’s t': {'r': 4, 'e': 0, 'u': 0},
#  '’s tr': {'a': 5},
#  's tra': {'n': 30, 'd': 22, 'i': 5, 'v': 6, 'f': 1, 'g': 0, 'p': 0},
#  ' tran': {'s': 331, 'q': 4},
#  'trans': {'f': 173,
#   's': 0,
#   'p': 81,
#   'i': 30,
#   'm': 20,
#   'a': 2,
#   'l': 14,
#   'n': 0,
#   'g': 0,
#   '-': 4},
#  'forma': {'t': 170, 'n': 15, 'l': 12},
#  'ormat': {'i': 166, 's': 1, '.': 1, ' ': 1},
#  'rmati': {'o': 159, 'v': 8, ' ': 0},
#  'matio': {'n': 160},
#  'tion.': {'\n': 111, ' ': 569, '”': 1},
#  'ion.\n': {'O': 10,
#   '•': 3,
#   'S': 5,
#   'R': 0,
#   'E': 3,
#   'P': 2,
#   'D': 4,
#   'B': 7,
#   'J': 1,
#   'F': 6,
#   'G': 0,
#   'W': 33,
#   'T': 34,
#   'I': 27,
#   'M': 7,
#   'L': 4,
#   '#': 0,
#   'A': 9,
#   'N': 0,
#   ' ': 1,
#   'Y': 0,
#   'C': 0,
#   '9': 0,
#   'U': 0,
#   'H': 0},
#  'on.\nO': {'n': 2, 'u': 6, 'r': 0},
#  'n.\nOn': {'e': 0, 'c': 1},
#  '.\nOne': {' ': 6, ',': 1},
#  '\nOne ': {'o': 10, 'i': 2, 'w': 0, 'a': 0, 't': 0, 'r': 0},
#  'One o': {'f': 22},
#  'ne of': {' ': 214},
#  'e of ': {'N': 16,
#   'c': 87,
#   's': 78,
#   't': 583,
#   'e': 68,
#   'o': 162,
#   'h': 84,
#   'M': 25,
#   'E': 6,
#   'I': 91,
#   'g': 49,
#   'a': 111,
#   'm': 64,
#   'y': 42,
#   'S': 25,
#   'i': 67,
#   'u': 26,
#   'A': 28,
#   'd': 76,
#   'p': 86,
#   '1': 7,
#   'r': 32,
#   'w': 33,
#   'f': 37,
#   'H': 6,
#   "'": 0,
#   '3': 17,
#   '“': 8,
#   'n': 12,
#   'k': 10,
#   'B': 21,
#   'G': 22,
#   'P': 7,
#   'J': 8,
#   'L': 10,
#   'K': 9,
#   'D': 18,
#   'F': 9,
#   '"': 2,
#   'l': 26,
#   'v': 10,
#   'C': 30,
#   'b': 18,
#   '8': 0,
#   'U': 6,
#   'j': 2,
#   'q': 0,
#   'T': 9,
#   '4': 1,
#   '7': 6,
#   '2': 4,
#   'Y': 10,
#   'स': 0,
#   '‘': 1,
#   'V': 4,
#   'अ': 0,
#   'R': 3,
#   '6': 1,
#   'O': 3,
#   'W': 0,
#   '5': 0},
#  ' of N': {'I': 1, 'a': 39, 'e': 11, 'o': 19, 'C': 0, 'D': 0},
#  'of NI': {'T': 1},
#  'f NIT': {'I': 1},
#  'NITI’': {'s': 0},
#  'ITI’s': {' ': 0},
#  'TI’s ': {'f': 0},
#  'I’s f': {'u': 0},
#  '’s fu': {'n': 0, 'l': 1, 't': 10},
#  's fun': {'c': 3, 'd': 5},
#  ' func': {'t': 27},
#  'funct': {'i': 27},
#  'uncti': {'o': 28},
#  'nctio': {'n': 46},
#  'ction': {'s': 127,
#   '.': 101,
#   '\n': 1,
#   ' ': 353,
#   'i': 8,
#   '-': 4,
#   ',': 20,
#   'e': 9,
#   'a': 5,
#   ':': 1,
#   '…': 0,
#   '’': 2,
#   '”': 3,
#   '?': 0,
#   ';': 2,
#   'l': 0,
#   ')': 0},
#  'ons i': {'s': 8, 'n': 83, 'm': 0, 'f': 1, 't': 0},
#  'ns is': {':': 0, ' ': 14},
#  's is:': {'\n': 0},
#  ' is:\n': {'-': 0},
#  'is:\n-': {' ': 0},
#  's:\n- ': {'t': 0},
#  ':\n- t': {'o': 0},
#  '\n- to': {' ': 2},
#  '- to ': {'m': 0, 'b': 1, 'c': 0, 'f': 0, 'd': 0},
#  ' to m': {'a': 207, 'e': 106, 'i': 8, 'o': 68, 'y': 36, 'u': 0},
#  'to ma': {'i': 16,
#   'k': 151,
#   'n': 20,
#   'r': 13,
#   'c': 0,
#   'x': 1,
#   't': 1,
#   's': 0},
#  'o mai': {'n': 14, 'm': 0, 'l': 0},
#  ' main': {'s': 11, ' ': 12, 't': 30, 'l': 4},
#  'mains': {'t': 11, ' ': 35, ',': 0},
#  'ainst': {'r': 8, 'o': 2, ' ': 109, 'a': 2},
#  'instr': {'e': 8, 'u': 37},
#  'nstre': {'a': 10},
#  'strea': {'m': 19},
#  'tream': {' ': 9, 'l': 0, '.': 1, ';': 0, 'e': 0, 's': 4},
#  'ream ': {'e': 1,
#   'o': 42,
#   'a': 5,
#   'b': 0,
#   'f': 5,
#   'i': 6,
#   't': 9,
#   'j': 0,
#   's': 0,
#   'p': 0,
#   'w': 0,
#   'c': 0},
#  'eam e': {'x': 0, 'c': 0},
#  'am ex': {'t': 2, 'p': 1, 'c': 0},
#  'm ext': {'e': 0, 'r': 1},
#  ' exte': {'r': 11, 'n': 100},
#  'exter': {'n': 11, 'i': 0},
#  'xtern': {'a': 17},
#  'terna': {'l': 59, 't': 235},
#  'ernal': {' ': 48, 'l': 7, '.': 1, 'i': 0},
#  'rnal ': {'i': 1,
#   'a': 16,
#   'r': 2,
#   'A': 4,
#   'd': 1,
#   'M': 0,
#   'h': 0,
#   'm': 1,
#   'S': 0,
#   's': 3,
#   'e': 1,
#   'b': 0,
#   'p': 1,
#   'g': 0,
#   'c': 1,
#   'f': 0,
#   't': 0,
#   'v': 0},
#  'nal i': {'d': 3, 's': 14, 'n': 24},
#  'al id': {'e': 13},
#  'l ide': {'a': 7, 'o': 3, 'n': 4},
#  'deas ': {'i': 3,
#   'f': 6,
#   'b': 1,
#   'r': 0,
#   'a': 20,
#   'c': 1,
#   't': 2,
#   'm': 0,
#   'o': 6,
#   's': 0,
#   'w': 1},
#  'eas i': {'n': 8, 's': 1},
#  'as in': {'t': 8,
#   'd': 6,
#   ' ': 44,
#   'v': 6,
#   's': 2,
#   'c': 17,
#   'f': 3,
#   'a': 1,
#   'i': 1,
#   'e': 0,
#   'j': 0,
#   'p': 0},
#  's int': {'o': 45, 'e': 51, 'r': 2},
#  ' into': {' ': 224, 'l': 0, 'x': 2},
#  'into ': {'G': 1,
#   'p': 9,
#   'a': 54,
#   's': 8,
#   'N': 0,
#   't': 58,
#   "'": 0,
#   'i': 5,
#   'd': 9,
#   'e': 6,
#   'o': 13,
#   'I': 5,
#   'c': 7,
#   'g': 1,
#   'r': 6,
#   'f': 5,
#   'b': 6,
#   'y': 1,
#   'm': 5,
#   'T': 0,
#   'A': 1,
#   'l': 0,
#   'S': 0,
#   'j': 0,
#   'P': 0,
#   '‘': 0},
#  'nto G': {'o': 0, 'a': 0},
#  'to Go': {'v': 2, 'd': 5, 'o': 0},
#  'o Gov': {'e': 3},
#  ' Gove': {'r': 288},
#  'Gover': {'n': 300},
#  'overn': {'m': 789, 'a': 96, ' ': 2, 'i': 6, 'o': 13, 'e': 0},
#  'vernm': {'e': 789},
#  'ernme': {'n': 789},
#  'rnmen': {'t': 789},
#  'nment': {' ': 606,
#   '’': 14,
#   's': 101,
#   ',': 81,
#   '-': 2,
#   '.': 114,
#   'a': 32,
#   "'": 1,
#   '\n': 0,
#   ';': 3,
#   '`': 4,
#   '!': 1,
#   '?': 2},
#  'ent p': {'o': 18, 'e': 20, 'l': 7, 'a': 45, 'r': 30, 'i': 0, 'h': 0},
#  'nt po': {'l': 10, 's': 0, 'p': 2, 't': 1, 'i': 1, 'w': 0, 'r': 0},
#  't pol': {'i': 34},
#  ' poli': {'c': 238, 't': 139, 'o': 9, 's': 5},
#  'polic': {'i': 90, 'y': 105, 'e': 41},
#  'olici': {'e': 92, 'n': 0},
#  'licie': {'s': 92},
#  'icies': {',': 10, ' ': 62, '.': 16, '!': 0, ';': 0},
#  'cies,': {' ': 95, '\n': 12},
#  'ies, ': {'t': 31,
#   'M': 2,
#   'I': 12,
#   'a': 29,
#   'L': 4,
#   'i': 16,
#   'b': 18,
#   'w': 17,
#   'y': 4,
#   'h': 3,
#   'K': 0,
#   'e': 8,
#   'n': 2,
#   'S': 2,
#   '\n': 39,
#   'T': 1,
#   'p': 6,
#   'c': 7,
#   's': 8,
#   'o': 5,
#   'v': 1,
#   'W': 0,
#   'l': 3,
#   'r': 2,
#   'C': 2,
#   'd': 1,
#   'G': 0,
#   'm': 2,
#   'f': 7,
#   'D': 0,
#   'u': 2,
#   'N': 0,
#   'A': 1,
#   'B': 2,
#   ' ': 1,
#   'E': 1},
#  'es, t': {'h': 77, 'e': 3, 'o': 14, 'i': 1, 'a': 3, 'r': 1},
#  's, th': {'r': 5, 'e': 220, 'i': 22, 'a': 13, 'u': 1, 'o': 2},
#  ', thr': {'o': 20, 'i': 0, 'e': 6},
#  ' thro': {'u': 323, 'w': 5, 'n': 1, 'b': 0, 'a': 1},
#  'throu': {'g': 326},
#  'hroug': {'h': 352},
#  'rough': {' ': 338, 't': 83, 'o': 15, '\n': 1, '.': 2, 'l': 1, 's': 0},
#  'ough ': {'c': 18,
#   'w': 9,
#   't': 130,
#   's': 23,
#   'I': 7,
#   'Y': 2,
#   'T': 0,
#   'y': 5,
#   'a': 35,
#   'o': 21,
#   'd': 20,
#   'i': 22,
#   "'": 0,
#   'M': 8,
#   'l': 4,
#   'r': 8,
#   'f': 5,
#   '5': 0,
#   'P': 5,
#   'm': 9,
#   'p': 10,
#   'n': 3,
#   'u': 2,
#   'b': 7,
#   ' ': 0,
#   'h': 11,
#   'A': 3,
#   'e': 9,
#   'C': 1,
#   '“': 2,
#   'N': 2,
#   'v': 1,
#   'k': 2,
#   'g': 0,
#   'E': 0,
#   '1': 0,
#   'G': 0,
#   'D': 0,
#   'S': 0,
#   'J': 0,
#   'U': 0},
#  'ugh c': {'o': 8, 'e': 4, 'u': 0, 'r': 1, 'h': 0, 'a': 0},
#  'gh co': {'l': 1, 's': 1, 'n': 3, 'r': 0, 'o': 0, 'm': 0},
#  'h col': {'l': 6},
#  ' coll': {'a': 53, 'e': 142},
#  'colla': {'b': 50, 't': 1, 'p': 0},
#  'ollab': {'o': 51},
#  'llabo': {'r': 51},
#  'labor': {'a': 62, ' ': 0},
#  'abora': {'t': 63},
#  'borat': {'i': 39, 'o': 11, 'e': 11},
#  'orati': {'o': 58, 'v': 4, 'n': 5},
#  'ratio': {'n': 855, ' ': 1, '.': 1},
#  'on wi': {'t': 75, 'l': 57, 'n': 0},
#  'n wit': {'h': 110, 'n': 2},
#  ' with': {' ': 1773,
#   'o': 108,
#   'i': 100,
#   '\n': 0,
#   'd': 0,
#   ',': 1,
#   '.': 2,
#   'e': 0},
#  'with ': {'n': 36,
#   't': 514,
#   'b': 14,
#   'p': 50,
#   'S': 29,
#   'g': 36,
#   'M': 15,
#   'y': 117,
#   'h': 35,
#   'a': 194,
#   'A': 35,
#   'l': 9,
#   'o': 91,
#   'i': 46,
#   'm': 57,
#   'J': 4,
#   's': 70,
#   'Q': 2,
#   'C': 24,
#   'c': 43,
#   'r': 24,
#   'e': 54,
#   '‘': 0,
#   'w': 34,
#   'K': 7,
#   'f': 35,
#   'd': 24,
#   'I': 22,
#   'u': 28,
#   'F': 2,
#   'v': 8,
#   'P': 24,
#   'T': 4,
#   'N': 5,
#   '8': 3,
#   'U': 2,
#   '-': 0,
#   'G': 3,
#   '2': 1,
#   'j': 6,
#   'z': 3,
#   'R': 2,
#   'V': 1,
#   'B': 11,
#   '1': 1,
#   'E': 2,
#   'D': 0,
#   'X': 0,
#   'H': 0,
#   '7': 0,
#   '"': 0,
#   'Y': 0},
#  'ith n': {'a': 14, 'e': 12, 'u': 0, 'o': 7},
#  'th na': {'t': 18},
#  'h nat': {'i': 9, 'u': 14},
#  ' nati': {'o': 622, 'v': 3},
#  'natio': {'n': 1030},
#  'nal a': {'n': 49,
#   'g': 3,
#   't': 3,
#   'r': 5,
#   's': 0,
#   'c': 4,
#   'v': 3,
#   'd': 0,
#   'b': 1,
#   'i': 0},
#  'nd in': {'t': 66,
#   ' ': 130,
#   'v': 41,
#   'a': 0,
#   'f': 41,
#   'n': 30,
#   's': 38,
#   'd': 22,
#   'c': 21,
#   'e': 0,
#   'i': 3,
#   'j': 0,
#   'b': 0},
#  'd int': {'e': 89, 'o': 29, 'r': 1},
#  ' inte': {'r': 461, 'g': 92, 'l': 44, 'n': 93},
#  'inter': {'n': 170,
#   ' ': 4,
#   'e': 169,
#   'a': 34,
#   'v': 30,
#   '-': 31,
#   'c': 5,
#   'p': 5,
#   'f': 5,
#   's': 4,
#   'l': 5,
#   'd': 1,
#   'r': 2,
#   't': 0,
#   'm': 0,
#   'i': 0},
#  'ntern': {'a': 242, 'e': 7, 's': 0},
#  'ernat': {'i': 232, 'e': 2},
#  'rnati': {'o': 224, 'v': 7},
#  'nal e': {'x': 10,
#   'd': 1,
#   'c': 9,
#   'n': 11,
#   'f': 1,
#   't': 0,
#   'v': 1,
#   'a': 0,
#   'm': 0,
#   'r': 0,
#   'l': 1},
#  'al ex': {'p': 16, 'e': 1, 'c': 6, 't': 0, 'i': 0},
#  'l exp': {'e': 18, 'a': 12, 'l': 2, 'o': 1},
#  ' expe': {'r': 228, 'c': 67, 'n': 26, 'd': 4},
#  'exper': {'t': 49, 'i': 178},
#  'xpert': {'s': 31, 'i': 16, ' ': 1},
#  'perts': {';': 0, ' ': 24, '.': 2, ',': 1, ':': 0},
#  'erts;': {'\n': 0},
#  'rts;\n': {'-': 0, 'R': 0, 'I': 0},
#  'ts;\n-': {' ': 0},
#  's;\n- ': {'t': 1},
#  ';\n- t': {'o': 1},
#  ' to b': {'e': 435,
#   'r': 61,
#   'u': 81,
#   'o': 29,
#   'a': 12,
#   'y': 1,
#   'l': 2,
#   'i': 0},
#  'to be': {' ': 361,
#   'n': 12,
#   'c': 33,
#   'q': 0,
#   '\n': 1,
#   'i': 2,
#   'g': 4,
#   't': 2,
#   'l': 5,
#   'a': 4,
#   'r': 0,
#   'd': 0,
#   'm': 0},
#  'o be ': {'t': 21,
#   'a': 78,
#   'd': 17,
#   'm': 14,
#   'w': 17,
#   'c': 25,
#   'b': 13,
#   's': 27,
#   'r': 12,
#   'l': 8,
#   'p': 18,
#   'i': 23,
#   'R': 0,
#   'o': 13,
#   'h': 43,
#   'f': 12,
#   ' ': 0,
#   'g': 5,
#   'e': 11,
#   'u': 3,
#   'y': 3,
#   'K': 1,
#   'I': 0,
#   'v': 4,
#   'J': 0,
#   'T': 0,
#   'q': 0,
#   'n': 1,
#   'S': 1,
#   'M': 0,
#   'N': 0,
#   "'": 0,
#   'k': 0},
#  ' be t': {'h': 107, 'o': 15, 'a': 20, 'r': 8, 'e': 2, 'i': 0},
#  'be th': {'e': 96, 'a': 5, 'o': 1, 'i': 4, 'r': 0},
#  'e the': {' ': 1281,
#   'i': 85,
#   'r': 56,
#   's': 39,
#   'm': 114,
#   'y': 47,
#   'n': 26,
#   'f': 0,
#   '\n': 0,
#   'o': 1},
#  'the G': {'o': 78,
#   'l': 10,
#   'i': 3,
#   'u': 6,
#   'e': 12,
#   'S': 2,
#   'D': 2,
#   '2': 3,
#   'a': 9,
#   '-': 3,
#   'y': 0,
#   '4': 0,
#   'r': 4,
#   ' ': 2},
#  'he Go': {'v': 87, 'o': 2, 'r': 0, 'd': 5, 'l': 0},
#  'e Gov': {'e': 108, 't': 1},
#  'ment’': {'s': 15},
#  'ent’s': {' ': 20},
#  'nt’s ': {'l': 0,
#   'w': 0,
#   'f': 0,
#   's': 1,
#   'M': 0,
#   'e': 0,
#   'c': 2,
#   'p': 2,
#   'a': 3,
#   'm': 0,
#   'i': 0,
#   'n': 1,
#   'r': 0,
#   'h': 0},
#  't’s l': {'i': 0},
#  '’s li': {'n': 0, 's': 2, 'f': 6, 'v': 0},
#  's lin': {'k': 9, 'g': 1, 'e': 0},
#  ' link': {' ': 19, 's': 57, 'e': 40, 'i': 1, 'a': 15, ',': 1, '.': 0},
#  'link ': {'t': 2,
#   'f': 2,
#   'b': 7,
#   'r': 3,
#   's': 1,
#   'w': 1,
#   'e': 0,
#   'y': 0,
#   'u': 0},
#  ' to t': {'h': 1007,
#   'a': 147,
#   'w': 5,
#   'r': 67,
#   'o': 14,
#   'i': 7,
#   'e': 49,
#   'u': 5},
#  'to th': {'e': 886, 'i': 124, 'a': 40, 'o': 13, 'r': 4},
#  'o the': {' ': 881,
#   's': 25,
#   'n': 2,
#   'i': 30,
#   'm': 30,
#   '\n': 0,
#   'r': 7,
#   'y': 4,
#   'o': 0},
#  'the o': {'u': 16,
#   'r': 13,
#   'c': 40,
#   't': 61,
#   'p': 80,
#   'n': 63,
#   'f': 13,
#   'd': 1,
#   'l': 22,
#   'w': 3,
#   'b': 6,
#   'v': 1,
#   'i': 0,
#   'a': 0},
#  'he ou': {'t': 18},
#  'e out': {'s': 16, 'c': 21, ' ': 44, 'l': 5, 'p': 1, ',': 0},
#  ' outs': {'i': 44, 't': 22, 'e': 1, 'o': 3},
#  'outsi': {'d': 44},
#  'utsid': {'e': 45},
#  'tside': {' ': 33, '.': 7, ',': 0, ';': 0, 'r': 1},
#  'side ': {'w': 2,
#   'e': 7,
#   'a': 4,
#   'I': 2,
#   'h': 2,
#   'o': 7,
#   'i': 2,
#   't': 16,
#   'M': 0,
#   'A': 1,
#   'U': 0,
#   'f': 0,
#   'y': 2,
#   'b': 2,
#   'm': 0,
#   'D': 3,
#   'k': 0,
#   'K': 0,
#   'G': 0},
#  'ide w': {'o': 1, 'h': 6, 'e': 0, 'i': 1, 'r': 0, 'a': 0},
#  'de wo': {'r': 1},
#  'e wor': {'l': 696, 'd': 43, 'k': 145, 'r': 4, 't': 2, 's': 6},
#  ' worl': {'d': 924},
#  'world': {',': 85,
#   '’': 32,
#   '.': 296,
#   ' ': 445,
#   "'": 25,
#   ';': 9,
#   'w': 3,
#   'v': 0,
#   '-': 2,
#   ':': 0,
#   'l': 0,
#   's': 0,
#   '`': 10,
#   '?': 3,
#   '"': 0},
#  'orld,': {' ': 86},
#  'rld, ': {'o': 5,
#   'i': 11,
#   'f': 2,
#   'a': 7,
#   'I': 8,
#   '1': 0,
#   'b': 2,
#   'S': 1,
#   't': 12,
#   'L': 0,
#   'e': 1,
#   'w': 13,
#   'l': 0,
#   'm': 1,
#   'c': 1,
#   'y': 0,
#   'h': 1,
#   ' ': 0,
#   'v': 0,
#   'k': 0,
#   's': 0,
#   '"': 0},
#  'ld, o': {'u': 2, 'n': 2, 'w': 0},
#  'd, ou': {'t': 0, 'r': 26},
#  ', out': {'s': 0, ' ': 7, 'e': 1},
#  'ide e': {'x': 0, 'n': 0, 'm': 8, 'l': 3, 'f': 5, 'q': 1, 'a': 0, 'y': 0},
#  'de ex': {'p': 1, 'i': 0, 'c': 0},
#  'e exp': {'e': 61, 'r': 21, 'l': 11, 'o': 10, 'a': 12},
#  'erts ': {'a': 4,
#   'w': 3,
#   'o': 3,
#   'h': 3,
#   ' ': 0,
#   'i': 0,
#   's': 2,
#   't': 2,
#   'f': 0,
#   'm': 0},
#  'rts a': {'n': 35, 'r': 16, 'i': 0, 'g': 1, 'c': 0, 's': 0, ' ': 1, 't': 1},
#  'ts an': {'d': 256, 'c': 2, 'g': 1, ' ': 2, 'y': 1},
#  'and p': {'r': 282,
#   'a': 32,
#   'u': 21,
#   'o': 55,
#   'l': 25,
#   'h': 4,
#   'e': 69,
#   'i': 2,
#   's': 0},
#  'nd pr': {'a': 12, 'o': 212, 'e': 32, 'i': 27, 'u': 0},
#  'd pra': {'c': 11, 'i': 0, 'y': 1},
#  ' prac': {'t': 72},
#  'pract': {'i': 72},
#  'racti': {'t': 10, 'o': 23, 'c': 54, 'v': 18, 'n': 5, 's': 6},
#  'actit': {'i': 10},
#  'ctiti': {'o': 10},
#  'titio': {'n': 42},
#  'ition': {'e': 14,
#   '.': 31,
#   ' ': 223,
#   's': 105,
#   ',': 42,
#   'a': 95,
#   'i': 0,
#   ';': 2,
#   '?': 0},
#  'tione': {'r': 11, 'd': 45},
#  'ioner': {'s': 6, ',': 0, '…': 0, '.': 3, ' ': 0},
#  'oners': {';': 0, ' ': 3, '.': 1, ',': 0},
#  'ners;': {'\n': 0},
#  'ers;\n': {'-': 0, 'F': 0},
#  'rs;\n-': {' ': 0},
#  'the i': {'n': 204, 'm': 79, 's': 41, 'l': 1, 'c': 0, 'd': 21, 'g': 0},
#  'he in': {'s': 31,
#   'a': 4,
#   ' ': 0,
#   't': 67,
#   'c': 20,
#   'f': 27,
#   'p': 1,
#   'i': 15,
#   'v': 12,
#   'n': 14,
#   'j': 0,
#   'd': 15,
#   'h': 3,
#   'e': 0,
#   'l': 0},
#  'e ins': {'t': 40, 'p': 29, 'u': 10, 'e': 2, 'i': 5},
#  'nstru': {'m': 27, 'c': 69},
#  'strum': {'e': 27},
#  'trume': {'n': 27},
#  'rumen': {'t': 27},
#  'ument': {' ': 12, 's': 26, '.': 1, 'a': 2},
#  'ent t': {'h': 155,
#   'o': 207,
#   'i': 16,
#   'r': 10,
#   'e': 7,
#   'y': 2,
#   'a': 1,
#   'w': 0},
#  'nt th': {'r': 7, 'a': 119, 'e': 55, 'u': 0, 'i': 15, 'o': 1},
#  't thr': {'o': 14, 'e': 14},
#  'ugh w': {'h': 3, 'e': 2, 'i': 2, 'a': 0},
#  'gh wh': {'i': 3, 'o': 0},
#  'h whi': {'c': 20},
#  ' whic': {'h': 621},
#  'which': {' ': 613, '\n': 0, ',': 7, ':': 0, 'w': 0, 'e': 0},
#  'hich ': {'i': 122,
#   'm': 21,
#   'w': 120,
#   'a': 43,
#   'I': 28,
#   'h': 55,
#   'd': 13,
#   'g': 7,
#   'b': 8,
#   'f': 6,
#   't': 37,
#   '1': 1,
#   's': 20,
#   'u': 1,
#   'c': 38,
#   'e': 14,
#   'p': 16,
#   'y': 18,
#   'F': 0,
#   'r': 5,
#   'B': 0,
#   'o': 9,
#   'n': 3,
#   'P': 1,
#   'l': 5,
#   'q': 0,
#   'C': 0,
#   'S': 0,
#   'M': 0,
#   'k': 0},
#  'ich i': {'d': 0, 's': 100, 'n': 18, 't': 6, 'm': 1},
#  'ch id': {'e': 0},
#  'h ide': {'a': 1},
#  'eas f': {'r': 4, 'o': 2},
#  'as fr': {'o': 9, 'a': 2, 'u': 0},
#  's fro': {'m': 285, 'n': 1},
#  ' from': {' ': 1195, '\n': 1, '.': 0, ',': 0},
#  'from ': {'o': 68,
#   'I': 57,
#   't': 367,
#   'i': 34,
#   'e': 28,
#   'a': 114,
#   'b': 11,
#   'C': 16,
#   'H': 3,
#   'c': 24,
#   'd': 23,
#   'R': 9,
#   'B': 10,
#   'V': 4,
#   'm': 32,
#   's': 28,
#   'S': 20,
#   'r': 5,
#   'w': 18,
#   'P': 7,
#   'y': 17,
#   'f': 15,
#   'p': 22,
#   'h': 33,
#   'D': 8,
#   'K': 10,
#   'v': 7,
#   'E': 1,
#   'F': 1,
#   'A': 23,
#   'T': 10,
#   '9': 1,
#   '"': 0,
#   '1': 18,
#   'N': 6,
#   'J': 5,
#   'L': 4,
#   '-': 0,
#   '5': 4,
#   '8': 1,
#   'u': 6,
#   '2': 5,
#   'G': 9,
#   'M': 19,
#   'l': 6,
#   '3': 3,
#   'n': 12,
#   "'": 1,
#   'W': 1,
#   'Y': 1,
#   'Z': 0,
#   'g': 4,
#   'j': 0,
#   '6': 1,
#   '4': 2,
#   'k': 0,
#   'U': 4,
#   'X': 0,
#   '.': 0,
#   'Q': 0,
#   'O': 0},
#  'rom o': {'u': 52, 't': 6, 'v': 1, 'n': 7, 'c': 0},
#  'om ou': {'t': 8, 'r': 43},
#  'm out': {'s': 8, 'p': 0, ' ': 1},
#  'ide a': {'r': 1, 'n': 26, ' ': 27, 'd': 1, 'l': 3, 's': 5, 'u': 0, 'f': 0},
#  'de ar': {'e': 2},
#  'e are': {' ': 1089,
#   'a': 58,
#   '\n': 0,
#   '.': 3,
#   'n': 1,
#   ':': 0,
#   ',': 1,
#   '”': 0},
#  ' are ': {'i': 125,
#   'n': 149,
#   'v': 30,
#   'b': 92,
#   'a': 311,
#   'd': 77,
#   'o': 75,
#   'e': 108,
#   't': 249,
#   'f': 90,
#   'p': 128,
#   's': 153,
#   'c': 169,
#   'm': 133,
#   'y': 13,
#   'g': 61,
#   'k': 16,
#   'h': 56,
#   'w': 91,
#   'r': 79,
#   'l': 65,
#   'H': 0,
#   'j': 14,
#   '4': 2,
#   'q': 3,
#   '.': 0,
#   'u': 34,
#   'B': 0,
#   'R': 0,
#   'J': 0,
#   'C': 0,
#   '1': 3,
#   '“': 0,
#   '2': 0,
#   'G': 0,
#   'I': 0,
#   'M': 0,
#   'S': 0,
#   '5': 1,
#   'W': 0,
#   '8': 0},
#  'are i': {'n': 112, 't': 9, 'm': 15, 's': 7, 'g': 0, 'r': 0, '-': 0},
#  're in': {'c': 19,
#   't': 25,
#   'a': 1,
#   ' ': 173,
#   'n': 6,
#   'd': 7,
#   's': 12,
#   'v': 11,
#   'f': 4,
#   'i': 0,
#   'h': 1,
#   'e': 0,
#   'j': 0},
#  'e inc': {'o': 15, 'r': 54, 'i': 8, 'l': 24, 'u': 2, 'e': 0},
#  ' inco': {'r': 13, 'm': 50, 'n': 0},
#  'incor': {'p': 11, 'r': 1},
#  'ncorp': {'o': 11},
#  'corpo': {'r': 34},
#  'orpor': {'a': 51},
#  'rpora': {'t': 51},
#  'porat': {'e': 31, 'i': 19},
#  'orate': {'d': 6, 's': 3, ' ': 40},
#  'rated': {' ': 98, ',': 3, '.': 4},
#  'ted i': {'n': 154, 't': 6, 'f': 0, 's': 5, 'l': 0, 'm': 0, 'd': 0},
#  'ed in': {'t': 49,
#   ' ': 431,
#   'c': 9,
#   'f': 4,
#   's': 4,
#   'd': 5,
#   'n': 4,
#   'w': 0,
#   'i': 0,
#   'v': 6,
#   'j': 0,
#   '.': 1,
#   'h': 2},
#  'nto p': {'o': 2, 'r': 3, 'l': 0, 'e': 0, 'a': 0},
#  'to po': {'l': 7,
#   's': 7,
#   'w': 10,
#   'e': 1,
#   'r': 0,
#   'n': 1,
#   'i': 4,
#   'o': 1,
#   'c': 0},
#  'o pol': {'i': 6, 'l': 3},
#  'olicy': {'-': 2,
#   '.': 31,
#   ' ': 76,
#   ',': 6,
#   '\n': 0,
#   '”': 1,
#   ':': 1,
#   '’': 3,
#   'm': 0,
#   '`': 1},
#  'licy-': {'m': 1, 't': 0},
#  'icy-m': {'a': 1},
#  'cy-ma': {'k': 1},
#  'y-mak': {'i': 0, 'e': 0},
#  '-maki': {'n': 6},
#  'makin': {'g': 115},
#  'aking': {'.': 8, ' ': 223, '\n': 1, ',': 3},
#  'king.': {'\n': 2, ' ': 18},
#  'ing.\n': {'T': 2,
#   'B': 0,
#   'E': 1,
#   'W': 5,
#   'Y': 0,
#   'I': 14,
#   'M': 0,
#   'S': 3,
#   'A': 0,
#   '•': 1,
#   'F': 0,
#   'D': 0,
#   'O': 0,
#   '#': 0},
#  'ng.\nT': {'h': 2},
#  'g.\nTh': {'e': 1, 'a': 0},
#  '.\nThe': {' ': 154, 's': 8, 'r': 35, 'y': 3, 'n': 0, 'i': 1},
#  '\nThe ': {'G': 6,
#   'n': 10,
#   'w': 26,
#   'i': 11,
#   'S': 6,
#   'p': 34,
#   's': 35,
#   'f': 17,
#   'U': 6,
#   'A': 5,
#   'e': 12,
#   'F': 1,
#   'r': 21,
#   't': 21,
#   'I': 13,
#   'o': 7,
#   'a': 5,
#   'c': 20,
#   'd': 12,
#   'R': 1,
#   'm': 12,
#   'l': 11,
#   'E': 3,
#   'g': 13,
#   'C': 6,
#   'j': 2,
#   'N': 11,
#   'W': 2,
#   'J': 1,
#   'B': 2,
#   'v': 9,
#   'b': 7,
#   '2': 0,
#   'h': 1,
#   'T': 1,
#   'P': 4,
#   'y': 2,
#   'L': 1,
#   'u': 0,
#   '7': 0,
#   'M': 1,
#   '‘': 0,
#   'V': 0},
#  'The G': {'o': 19, 'l': 1, 'i': 0, 'a': 0, 'e': 0},
#  'ent o': {'f': 430,
#   'n': 57,
#   'u': 8,
#   'v': 4,
#   'r': 13,
#   'b': 0,
#   'p': 22,
#   'c': 1,
#   'w': 0},
#  'nt of': {' ': 488, 'f': 25},
#  't of ': {'I': 77,
#   'a': 85,
#   't': 413,
#   's': 38,
#   'o': 123,
#   'V': 2,
#   'c': 63,
#   'f': 27,
#   'Y': 0,
#   'p': 55,
#   '2': 9,
#   'l': 11,
#   'e': 30,
#   'h': 41,
#   'm': 45,
#   'y': 20,
#   'w': 20,
#   'i': 56,
#   '1': 10,
#   '7': 3,
#   'd': 17,
#   'b': 22,
#   'g': 18,
#   'M': 11,
#   'T': 8,
#   'J': 3,
#   'K': 11,
#   'A': 18,
#   'n': 12,
#   'N': 8,
#   '‘': 3,
#   'S': 17,
#   '6': 1,
#   'r': 22,
#   'G': 6,
#   'C': 9,
#   'O': 3,
#   'P': 12,
#   'E': 2,
#   'U': 4,
#   'H': 2,
#   'v': 9,
#   'B': 7,
#   'F': 0,
#   '"': 1,
#   'R': 12,
#   '3': 0,
#   'u': 7,
#   'q': 0,
#   '8': 0,
#   'k': 0,
#   'D': 2,
#   '“': 0,
#   '5': 3,
#   'j': 0,
#   'L': 0,
#   '\n': 0},
#  ' of I': {'n': 424, 's': 7, 'N': 3, 'r': 12, 'C': 0, 'T': 0, 'm': 0},
#  'of In': {'d': 412, 't': 6, 'f': 2, 'c': 0, 'i': 0},
#  'f Ind': {'i': 401, 'e': 13, 'u': 2, 'o': 1},
#  'dia a': {'n': 250,
#   's': 35,
#   'r': 25,
#   'c': 3,
#   'f': 0,
#   ' ': 15,
#   'l': 11,
#   't': 11,
#   'm': 1,
#   'g': 0,
#   'p': 0,
#   'd': 2,
#   'w': 0},
#  'ia an': {'d': 287, ' ': 4, 'n': 0},
#  'a and': {' ': 448, ',': 1},
#  'and t': {'h': 901,
#   'r': 109,
#   'o': 119,
#   'e': 107,
#   'w': 17,
#   'i': 13,
#   'a': 46,
#   'u': 3},
#  'nd th': {'e': 840, 'a': 139, 'r': 13, 'i': 113, 'o': 18, 'u': 4},
#  'd the': {' ': 1172,
#   'm': 68,
#   's': 22,
#   'i': 119,
#   'y': 45,
#   'r': 68,
#   'n': 46,
#   '\n': 1},
#  'the S': {'t': 50,
#   'a': 14,
#   'i': 9,
#   'm': 5,
#   'u': 23,
#   'h': 4,
#   'e': 21,
#   'w': 8,
#   'o': 13,
#   'U': 0,
#   'D': 1,
#   'c': 3,
#   'r': 2,
#   'A': 15,
#   'I': 0,
#   'C': 8,
#   'k': 0},
#  'he St': {'a': 47, 'o': 1, 'r': 4},
#  'e Sta': {'t': 45, 'r': 10},
#  ' Stat': {'e': 187, 'i': 0},
# ...
#   'n': 6,
#   'y': 2,
#   's': 10,
#   'm': 2,
#   ' ': 2,
#   'f': 6,
#   'j': 1,
#   'r': 5,
#   'u': 0,
#   '\n': 2,
#   'g': 1,
#   'G': 0,
#   'H': 0,
#   'p': 0,
#   'I': 0,
#   'M': 0},
#  'ty, i': {'n': 11, 't': 8, 'f': 3, '.': 0, 'm': 0},
#  'y, in': {' ': 25, 'c': 10, 't': 5, 'n': 0, 'f': 1, 'i': 0, 'v': 0, 'd': 0},
#  ', in ': {'a': 27,
#   't': 89,
#   'O': 0,
#   'l': 3,
#   'm': 10,
#   'v': 0,
#   'o': 9,
#   'J': 1,
#   '2': 6,
#   'f': 2,
#   'h': 1,
#   'I': 9,
#   'C': 0,
#   'E': 1,
#   'p': 9,
#   'M': 2,
#   's': 3,
#   'w': 13,
#   'A': 0,
#   'd': 3,
#   'e': 5,
#   'c': 7,
#   'i': 2,
#   'K': 0,
#   'H': 0,
#   'D': 1,
#   'T': 0,
#   'S': 2,
#   'y': 0,
#   'g': 0,
#   'Y': 0,
#   'N': 0,
#   '1': 0,
#   'b': 1,
#   'k': 0,
#   'F': 0},
#  ' in a': {' ': 269,
#   'n': 61,
#   'd': 38,
#   'l': 28,
#   'b': 2,
#   'c': 30,
#   'p': 4,
#   'r': 29,
#   'i': 1,
#   's': 2,
#   't': 3,
#   'g': 9,
#   'f': 0,
#   'm': 0,
#   'u': 0,
#   'v': 0},
#  'in a ': {'c': 29,
#   'f': 26,
#   's': 50,
#   'w': 24,
#   't': 8,
#   'm': 18,
#   'd': 15,
#   'p': 20,
#   'y': 7,
#   'b': 18,
#   'g': 10,
#   'n': 18,
#   'v': 18,
#   'r': 11,
#   'q': 1,
#   'h': 7,
#   'l': 3,
#   'u': 1,
#   'k': 0,
#   '1': 0,
#   'j': 0,
#   'o': 0},
#  'n a c': {'o': 39, 'h': 3, 'r': 2, 'e': 4, 'l': 7, 'i': 0, 'a': 1},
#  ' a co': {'u': 65,
#   'l': 13,
#   'n': 58,
#   'm': 103,
#   'o': 0,
#   'r': 7,
#   's': 7,
#   'a': 2,
#   '-': 2,
#   'h': 0},
#  'a cou': {'n': 54, 'l': 6, 'r': 5, 'p': 4, 'g': 0},
#  ' coun': {'t': 1279, 'c': 9, 's': 2},
#  'count': {'r': 1240,
#   ' ': 46,
#   'l': 9,
#   'a': 20,
#   'y': 1,
#   '.': 2,
#   's': 50,
#   'e': 30,
#   '\n': 0,
#   'i': 0,
#   ';': 0,
#   '’': 0},
#  'ountr': {'y': 859, 'i': 430},
#  'untry': {' ': 413,
#   ',': 88,
#   '.': 191,
#   'm': 120,
#   '’': 15,
#   "'": 7,
#   'w': 0,
#   ';': 3,
#   '-': 2,
#   '?': 7,
#   'a': 0,
#   '!': 1,
#   '\n': 0},
#  'ntry ': {'o': 30,
#   'h': 46,
#   'm': 7,
#   'c': 25,
#   'i': 42,
#   't': 35,
#   's': 25,
#   'w': 58,
#   'f': 27,
#   'a': 50,
#   'v': 1,
#   'b': 7,
#   'r': 8,
#   'u': 0,
#   'l': 7,
#   '–': 0,
#   'p': 4,
#   'g': 1,
#   'd': 7,
#   '"': 0,
#   'j': 0,
#   'e': 4,
#   'k': 2,
#   'n': 3,
#   '-': 2,
#   'y': 0,
#   'A': 0,
#   ' ': 0,
#   'I': 0},
#  'try o': {'f': 44, 'u': 2, 'n': 3, 'r': 3},
#  'ry of': {' ': 167, 'f': 2, 't': 0},
#  ' of g': {'l': 46, 'o': 62, 'a': 4, 'r': 81, 'e': 9, 'u': 4, 'i': 1},
#  'of gl': {'o': 44, 'a': 1},
#  'f glo': {'r': 0, 'b': 44},
#  ' glor': {'i': 14, 'y': 13},
#  'glori': {'o': 13, 'f': 1},
#  'lorio': {'u': 13},
#  'oriou': {'s': 16},
#  'rious': {' ': 103, 'l': 9, 'n': 1, '.': 2, ',': 0},
#  'ious ': {'d': 10,
#   'r': 3,
#   'y': 8,
#   'e': 11,
#   'b': 3,
#   'o': 21,
#   '1': 0,
#   'g': 18,
#   't': 21,
#   'p': 24,
#   'G': 3,
#   'A': 0,
#   'i': 18,
#   's': 14,
#   'f': 7,
#   'a': 20,
#   'c': 17,
#   'R': 0,
#   'n': 3,
#   'l': 9,
#   'B': 1,
#   'w': 3,
#   'h': 1,
#   'm': 5,
#   'I': 1,
#   'M': 0,
#   'j': 0,
#   'q': 0,
#   'v': 2,
#   'C': 0},
#  'ous d': {'i': 3, 'a': 3, 'e': 3, 'u': 0, 'y': 0},
#  'us di': {'v': 0, 's': 3, 'm': 0},
#  's div': {'e': 26, 'i': 3},
#  ' dive': {'r': 111, 's': 2},
#  'diver': {'s': 109, 't': 8},
#  'ivers': {'i': 174, 'a': 101, 'e': 22, ' ': 21, ';': 1, ',': 4, '.': 9},
#  'versi': {'t': 165, 'o': 9, 'f': 6, 'a': 0, 'n': 0},
#  'ersit': {'y': 139, 'i': 25},
#  'rsity': {'.': 37, ' ': 83, ',': 11, ';': 2, '\n': 2},
#  'sity.': {' ': 31, '\n': 8},
#  'ity. ': {'T': 36,
#   'I': 43,
#   'H': 6,
#   'A': 19,
#   'E': 1,
#   'B': 6,
#   'W': 32,
#   'S': 3,
#   'J': 0,
#   'C': 6,
#   'O': 5,
#   '\n': 101,
#   'Y': 2,
#   'M': 6,
#   'N': 5,
#   ' ': 2,
#   'R': 0,
#   'U': 1,
#   'L': 1,
#   'G': 2,
#   'F': 0,
#   'P': 0,
#   'D': 1,
#   ';': 0,
#   'Q': 0},
#  'ty. T': {'h': 50, 'o': 1, 'i': 0},
#  'y. Th': {'e': 122, 'i': 60, 'a': 10, 'r': 2, 'o': 0},
#  '. The': {'s': 100, ' ': 619, 'r': 276, 'y': 195, 'i': 21, 'n': 24, '\n': 1},
#  ' Thes': {'e': 110},
#  'These': {' ': 143, ',': 1},
#  'hese ': {'a': 78,
#   'e': 22,
#   's': 64,
#   'c': 26,
#   'w': 23,
#   'y': 3,
#   'o': 10,
#   'P': 2,
#   't': 54,
#   'p': 47,
#   'd': 24,
#   '3': 2,
#   'm': 16,
#   '9': 0,
#   '2': 3,
#   'i': 48,
#   'f': 18,
#   'h': 6,
#   'g': 18,
#   'F': 0,
#   'b': 17,
#   'r': 14,
#   'l': 9,
#   '5': 1,
#   'q': 2,
#   'k': 4,
#   'u': 1,
#   '4': 0,
#   '1': 4,
#   'n': 6,
#   'v': 12,
#   'S': 1,
#   'B': 0,
#   'G': 1,
#   'j': 0,
#   'C': 0,
#   'T': 0,
#   '8': 0,
#   'J': 1},
#  'ese a': {'r': 60, 'l': 3, 'n': 5, 's': 1, 'c': 4, 't': 0, 'v': 0, 'w': 0},
#  'se ar': {'e': 66, 'c': 0},
#  'are n': {'o': 129, 'a': 4, 'e': 10, 'u': 3},
#  're no': {'t': 95, 'w': 31, ' ': 25, 'r': 0, 'n': 0, 'b': 0},
#  'e not': {' ': 166, 'i': 19, '\n': 0, 'h': 3, '-': 0, ',': 0, 'e': 0, 's': 0},
#  ' not ': {'s': 68,
#   'e': 42,
#   'g': 57,
#   'a': 137,
#   'o': 128,
#   'j': 130,
#   'n': 12,
#   'b': 132,
#   'h': 85,
#   'f': 59,
#   'v': 8,
#   'c': 39,
#   'w': 46,
#   'p': 34,
#   'i': 28,
#   't': 96,
#   'r': 45,
#   'l': 44,
#   'd': 44,
#   'k': 20,
#   'm': 45,
#   'u': 6,
#   'y': 4,
#   'A': 0,
#   'B': 0,
#   'G': 0},
#  'not s': {'m': 0,
#   'e': 13,
#   'o': 6,
#   't': 13,
#   'u': 19,
#   'h': 3,
#   'i': 4,
#   'l': 2,
#   'p': 2,
#   'c': 0,
#   'a': 6,
#   'w': 0},
#  'ot sm': {'a': 0},
#  't sma': {'l': 8},
#  ' smal': {'l': 141},
#  'small': {' ': 126, ',': 4, 'e': 7, '.': 3, 'y': 0},
#  'mall ': {'a': 20,
#   's': 9,
#   'c': 11,
#   't': 15,
#   'o': 0,
#   'e': 3,
#   'b': 7,
#   'i': 14,
#   'h': 3,
#   'f': 5,
#   'r': 2,
#   'g': 2,
#   'j': 0,
#   'I': 7,
#   'l': 2,
#   'd': 3,
#   'p': 11,
#   'n': 1,
#   'v': 2,
#   'w': 1,
#   'S': 0},
#  'all a': {'c': 3,
#   'n': 23,
#   'r': 17,
#   'g': 6,
#   'p': 0,
#   ' ': 6,
#   'v': 0,
#   'l': 3,
#   'w': 2,
#   'm': 3,
#   'i': 0,
#   'b': 1,
#   's': 2,
#   't': 0,
#   'f': 0},
#  'll ac': {'h': 6, 'c': 3, 't': 6, 'q': 1},
#  'l ach': {'i': 7},
#  ' achi': {'e': 230},
#  'achie': {'v': 231},
#  'chiev': {'e': 208, 'i': 21, 'a': 1},
#  'hieve': {'m': 53, 'd': 71, ' ': 81, '.': 0},
#  'ievem': {'e': 53},
#  'eveme': {'n': 53},
#  'vemen': {'t': 150},
#  'ement': {'s': 181,
#   'a': 46,
#   '.': 86,
#   ' ': 357,
#   ',': 35,
#   'e': 23,
#   ';': 5,
#   'i': 9,
#   '\n': 1,
#   ':': 0,
#   '”': 0,
#   '?': 0},
#  'ents.': {' ': 110, '\n': 16},
#  'nts. ': {'Y': 4,
#   'T': 17,
#   'O': 4,
#   'A': 8,
#   'I': 18,
#   '\n': 33,
#   'W': 21,
#   ' ': 3,
#   'H': 1,
#   'B': 2,
#   'E': 2,
#   'L': 1,
#   'S': 3,
#   'N': 0,
#   'G': 0,
#   '1': 0,
#   'F': 0,
#   'M': 0},
#  'ts. Y': {'e': 2, 'o': 8},
#  's. Ye': {'t': 4, 's': 2},
#  '. Yet': {',': 9, ' ': 2},
#  ' Yet,': {' ': 10},
#  'Yet, ': {'w': 4,
#   'o': 3,
#   ' ': 0,
#   'D': 0,
#   's': 0,
#   'I': 1,
#   't': 2,
#   'i': 0,
#   'd': 0,
#   'S': 0},
#  'et, w': {'e': 8, 'i': 0, 'h': 3},
#  't, we': {' ': 125, 's': 0, 'a': 0},
#  ', we ': {'n': 47,
#   'h': 278,
#   'm': 67,
#   'w': 151,
#   'c': 64,
#   'a': 198,
#   'r': 14,
#   's': 89,
#   'o': 5,
#   'j': 0,
#   'e': 7,
#   'k': 14,
#   't': 4,
#   'l': 23,
#   'v': 0,
#   'u': 4,
#   'i': 13,
#   'p': 10,
#   'd': 12,
#   'f': 14,
#   'g': 10,
#   'b': 3},
#  ' we n': {'o': 19, 'e': 82},
#  'we no': {'w': 4, 't': 12, 'r': 0, ' ': 0},
#  'e now': {' ': 62, 'a': 1, ',': 0, '.': 3, '!': 0, 'h': 0},
#  ' now ': {'l': 3,
#   'i': 17,
#   'I': 2,
#   't': 30,
#   'f': 7,
#   'w': 14,
#   'a': 32,
#   'b': 21,
#   'r': 7,
#   'v': 1,
#   'g': 2,
#   'h': 14,
#   'n': 3,
#   'o': 11,
#   'm': 6,
#   ' ': 1,
#   'c': 7,
#   'e': 5,
#   's': 3,
#   'y': 4,
#   'F': 0,
#   'u': 2,
#   'p': 3,
#   'd': 1,
#   'S': 0,
#   'j': 0,
#   'B': 0},
#  'now l': {'i': 2, 'o': 0},
#  'ow li': {'v': 0, 's': 1, 'n': 1},
#  'w liv': {'e': 0},
#  ' live': {' ': 78, 's': 180, 'd': 17, 'l': 20, ',': 0, '.': 2, 'r': 1},
#  'live ': {'i': 38,
#   'a': 17,
#   'f': 3,
#   'u': 3,
#   'b': 3,
#   'w': 9,
#   't': 0,
#   'c': 1,
#   's': 0,
#   'o': 1,
#   'y': 0,
#   'e': 0,
#   'M': 2},
#  'ive i': {'n': 88, 'd': 1, 't': 11, 'm': 12, 's': 6},
#  've in': {' ': 97,
#   'c': 23,
#   'i': 4,
#   'f': 4,
#   'd': 11,
#   'v': 18,
#   't': 29,
#   'h': 1,
#   's': 8,
#   '.': 4,
#   'n': 0,
#   '?': 0},
#  'e in ': {'a': 81,
#   't': 348,
#   'E': 2,
#   'P': 7,
#   '3': 1,
#   'r': 17,
#   'A': 18,
#   '4': 0,
#   'o': 57,
#   '1': 4,
#   'l': 17,
#   '6': 1,
#   'v': 3,
#   'd': 19,
#   'p': 24,
#   'e': 21,
#   'h': 25,
#   'j': 1,
#   'K': 5,
#   'B': 6,
#   'c': 21,
#   'M': 12,
#   'I': 154,
#   's': 36,
#   'b': 17,
#   'y': 14,
#   'm': 25,
#   'g': 14,
#   'G': 7,
#   'S': 16,
#   'i': 19,
#   'w': 10,
#   '2': 10,
#   'f': 10,
#   'L': 1,
#   'W': 2,
#   'H': 2,
#   'C': 5,
#   'N': 4,
#   '‘': 0,
#   'J': 3,
#   'U': 1,
#   'n': 8,
#   'R': 0,
#   'q': 0,
#   'D': 1,
#   'T': 1,
#   'F': 2,
#   'X': 0,
#   '“': 0,
#   '9': 0,
#   'V': 1,
#   'u': 1},
#  'in an': {' ': 31, 'o': 5, 'y': 15, 'd': 39, 'i': 0, 'c': 2, 'n': 0},
#  'n an ': {'a': 16, 'e': 16, 'O': 0, 'i': 14, 'A': 1, 'u': 7, 'o': 2, 'b': 0},
#  ' an a': {'g': 17,
#   't': 12,
#   'p': 4,
#   'n': 16,
#   'v': 1,
#   'c': 16,
#   'i': 4,
#   's': 9,
#   'd': 15,
#   'm': 21,
#   'r': 15,
#   'w': 2,
#   'l': 7,
#   'u': 5,
#   'b': 4},
#  'an ag': {'e': 7, 'r': 9, 'g': 0},
#  'n age': {' ': 7, '.': 1, 'n': 5},
#  ' age ': {'w': 0,
#   'o': 33,
#   'i': 1,
#   'a': 5,
#   'p': 2,
#   't': 3,
#   'c': 0,
#   'f': 0,
#   'h': 5,
#   'g': 7,
#   'I': 0,
#   'r': 0,
#   'b': 0},
#  'age w': {'h': 7, 'a': 9, 'i': 9, 'o': 0, 'e': 0},
#  'ge wh': {'e': 1, 'i': 4, 'o': 3, 'a': 0},
#  ' wher': {'e': 276},
#  'where': {' ': 271,
#   '.': 16,
#   '\n': 0,
#   ',': 8,
#   'i': 13,
#   'v': 11,
#   ';': 0,
#   '!': 0,
#   'a': 1,
#   '?': 0},
#  'ere c': {'h': 1, 'o': 10, 'a': 19, 'r': 3, 'l': 1, 'e': 0, 'i': 1},
#  're ch': {'a': 14, 'i': 0, 'o': 0},
#  'e cha': {'n': 186, 'l': 51, 's': 0, 'i': 6, 'r': 12, 'm': 0, 'k': 1},
#  ' chan': {'g': 410, 'n': 20, 'c': 46, 't': 1},
#  'chang': {'e': 414, 'i': 46},
#  'hange': {' ': 214,
#   'd': 52,
#   ',': 23,
#   's': 65,
#   '\n': 2,
#   '.': 65,
#   ';': 3,
#   '?': 0},
#  'ange ': {'i': 67,
#   'f': 9,
#   'l': 0,
#   'h': 10,
#   'a': 32,
#   'o': 53,
#   't': 37,
#   'b': 2,
#   'c': 3,
#   'w': 5,
#   'S': 0,
#   'd': 2,
#   'p': 4,
#   'k': 1,
#   's': 2,
#   'r': 3,
#   'C': 9,
#   'm': 1,
#   'n': 1,
#   'y': 0,
#   ' ': 0,
#   'P': 0},
#  'nge i': {'s': 23, 'n': 45, 't': 2, 'f': 0},
#  'ge is': {' ': 38, '…': 0, 's': 0},
#  'e is ': {'c': 27,
#   'a': 191,
#   't': 68,
#   'p': 18,
#   'n': 120,
#   'w': 14,
#   'm': 21,
#   's': 32,
#   'o': 24,
#   'b': 19,
#   'g': 22,
#   'h': 5,
#   'v': 6,
#   'i': 17,
#   'f': 3,
#   'l': 8,
#   '\n': 0,
#   'j': 1,
#   'P': 0,
#   'B': 0,
#   '9': 0,
#   'd': 13,
#   'e': 8,
#   'u': 4,
#   '“': 1,
#   'A': 1,
#   'r': 9,
#   '‘': 0,
#   '7': 0,
#   'y': 3,
#   'k': 2,
#   'q': 1,
#   '1': 0,
#   'G': 0},
#  ' is c': {'o': 69, 'r': 23, 'e': 15, 'l': 16, 'h': 16, 'a': 9, 'u': 3},
#  'is co': {'n': 89, 'u': 51, 'm': 45, 'r': 1, 's': 0, 'o': 3, 'l': 2, 'h': 0},
#  's con': {'s': 42, 'n': 25, 'c': 25, 't': 59, 'f': 42, 'v': 7, 'd': 6},
#  ' cons': {'t': 140, 'e': 77, 'u': 50, 'i': 92, 'c': 30, 'o': 5, 'p': 2},
#  'const': {'a': 21, 'r': 70, 'i': 52},
#  'onsta': {'n': 20, 'b': 0},
#  'nstan': {'t': 22, 'c': 3},
#  'stant': {' ': 26, 'i': 21, 'l': 13, 's': 0},
#  'tant ': {'a': 29,
#   'c': 10,
#   't': 51,
#   'o': 5,
#   'i': 26,
#   'l': 9,
#   'd': 24,
#   's': 17,
#   'f': 43,
#   'v': 2,
#   'r': 17,
#   'p': 20,
#   'h': 2,
#   'e': 8,
#   'g': 5,
#   'm': 10,
#   'n': 5,
#   'b': 4,
#   'S': 0,
#   'y': 0,
#   'k': 0,
#   'P': 0,
#   'u': 0,
#   'j': 0},
#  'ant a': {'n': 21,
#   ' ': 7,
#   's': 12,
#   'r': 4,
#   't': 2,
#   'c': 1,
#   'd': 1,
#   'g': 1,
#   'm': 0},
#  'nt an': {'d': 272, 'n': 0, ' ': 2, 'a': 1, 'i': 0, 'g': 0},
#  't and': {' ': 601, ',': 3, '\n': 0},
#  'and w': {'e': 119, 'i': 105, 'h': 72, 'o': 43, 'a': 49, 'r': 5},
#  'nd we': {' ': 117, 'l': 13, 'a': 4, ',': 0, 'r': 3, 'n': 1},
#  'd we ': {'a': 25,
#   'k': 2,
#   'm': 4,
#   'l': 3,
#   'w': 28,
#   'c': 5,
#   'h': 34,
#   'e': 0,
#   'f': 1,
#   's': 8,
#   'd': 3,
#   'b': 1,
#   'n': 7,
#   'o': 1,
#   'p': 1,
#   'g': 0,
#   't': 2,
#   'r': 0},
#  ' we a': {'r': 358,
#   'p': 4,
#   'l': 67,
#   'c': 8,
#   's': 9,
#   'g': 3,
#   'd': 5,
#   't': 3,
#   'n': 2,
#   'v': 0,
#   'f': 0,
#   'i': 1,
#   'b': 0},
#  'we ar': {'e': 355, 'r': 2, 'g': 0},
#  'are v': {'a': 4, 'e': 17, 'i': 8, 'u': 0},
#  're va': {'r': 0, 'l': 4, 's': 1},
#  'e var': {'i': 9, 'd': 0},
#  ' vari': {'a': 0, 'o': 64, 'e': 7},
#  'varia': {'b': 2},
#  'ariab': {'l': 2},
#  'riabl': {'e': 0, 'y': 1},
#  'iable': {'s': 0, ' ': 8, ';': 1, '.': 1, ',': 0},
#  'ables': {'.': 2, ' ': 18, ',': 2, '\n': 0},
#  'bles.': {'\n': 1, ' ': 1},
#  'les.\n': {'W': 2, 'A': 1, 'I': 0, 'F': 0, 'M': 1, 'L': 0, '4': 0, 'E': 0},
#  'es.\nW': {'e': 28, 'i': 0, 'h': 4, 'a': 0},
#  's.\nWe': {' ': 83, ',': 0},
#  '.\nWe ': {'m': 19,
#   'h': 84,
#   'w': 44,
#   'c': 16,
#   'a': 65,
#   'p': 1,
#   'i': 4,
#   'v': 0,
#   'l': 6,
#   'g': 2,
#   'b': 5,
#   'n': 7,
#   'u': 0,
#   's': 22,
#   'f': 3,
#   'd': 7,
#   'r': 1,
#   'o': 1,
#   'e': 0},
#  '\nWe m': {'u': 47, 'e': 0, 'a': 0},
#  'We mu': {'s': 87},
#  'e mus': {'t': 211, 'i': 1, 'e': 0},
#  ' must': {' ': 485, ',': 0, ':': 0, '.': 0, 'e': 0},
#  'must ': {'c': 36,
#   'h': 67,
#   'k': 3,
#   'g': 4,
#   'b': 98,
#   's': 32,
#   'm': 9,
#   'e': 14,
#   'l': 9,
#   'r': 23,
#   'f': 9,
#   'a': 75,
#   'p': 12,
#   'n': 19,
#   'w': 7,
#   'd': 19,
#   'R': 1,
#   't': 18,
#   'i': 4,
#   'v': 0,
#   'u': 5,
#   'j': 0},
#  'ust c': {'h': 5, 'o': 34, 'a': 5, 'r': 0, 'u': 0, 'e': 0},
#  'st ch': {'a': 15, 'o': 0},
#  't cha': {'n': 18, 'l': 13, 'r': 4, 'm': 0},
#  'nge f': {'o': 9, 'r': 3},
#  'ge fo': {'r': 32, 'u': 1},
#  'e for': {' ': 508,
#   'c': 42,
#   'g': 8,
#   'w': 58,
#   't': 17,
#   'm': 52,
#   'e': 20,
#   'u': 3,
#   'b': 0},
#  'for b': {'o': 20, 'u': 11, 'r': 10, 'e': 7, 'a': 0},
#  'or bo': {'t': 17, 'r': 0, 'y': 2, 'o': 1, 'd': 0},
#  'r bot': {'h': 17, 't': 1},
#  ' both': {' ': 203, '.': 4, ':': 0, ',': 0, 'e': 8},
#  'both ': {'e': 1,
#   'o': 31,
#   'i': 13,
#   'w': 8,
#   's': 22,
#   'K': 0,
#   't': 17,
#   'c': 17,
#   'r': 6,
#   'm': 5,
#   'v': 2,
#   'b': 0,
#   'l': 4,
#   'd': 6,
#   'f': 6,
#   'h': 9,
#   'a': 13,
#   'u': 2,
#   'S': 0,
#   'n': 4,
#   'R': 0,
#   'H': 0,
#   'I': 5,
#   'A': 0,
#   '-': 0,
#   'C': 0,
#   'g': 1,
#   'P': 1,
#   'p': 1,
#   'k': 0},
#  'oth e': {'x': 1, 'a': 0},
#  'th ex': {'t': 0, 'a': 1, 'p': 2, 'c': 1},
#  'h ext': {'e': 2},
#  'nal r': {'e': 26, 'u': 3, 'o': 1, 'a': 1},
#  'al re': {'a': 5,
#   'c': 3,
#   'l': 36,
#   'f': 18,
#   's': 71,
#   'v': 4,
#   'm': 2,
#   'g': 8,
#   'p': 2,
#   'n': 0,
#   'q': 0},
#  'l rea': {'s': 3, 'l': 11, 'c': 6, 'p': 1},
#  ' reas': {'o': 81, 's': 4},
#  'reaso': {'n': 81},
#  'eason': {'s': 19, '.': 6, ',': 11, '?': 0, ' ': 55, 'e': 1, 'a': 4},
#  'asons': {'.': 8, ' ': 6, '\n': 0, ',': 2},
#  'sons.': {' ': 11, '\n': 0},
#  'ons. ': {'E': 5,
#   'T': 36,
#   'I': 38,
#   'A': 20,
#   '\n': 82,
#   'B': 13,
#   'H': 7,
#   'W': 32,
#   'Y': 4,
#   'N': 1,
#   'S': 9,
#   ' ': 4,
#   'O': 6,
#   'P': 1,
#   'F': 3,
#   'M': 4,
#   'D': 1,
#   'V': 0,
#   'J': 0,
#   'C': 0,
#   'G': 0},
#  'ns. E': {'a': 1, 'x': 0, 'q': 0, 'v': 2},
#  '. Eac': {'h': 14},
#  ' Each': {' ': 14},
#  'Each ': {'c': 0,
#   'o': 8,
#   'r': 0,
#   'a': 1,
#   'B': 0,
#   'e': 0,
#   'm': 0,
#   'd': 2,
#   'g': 0,
#   'y': 0},
#  'ach c': {'o': 1, 'a': 0, 'l': 0},
#  'ch co': {'u': 17, 'n': 6, 'o': 1, 'i': 0, 'l': 3, 'm': 2},
#  'h cou': {'n': 23, 'l': 8, 'r': 4, 'p': 0},
#  'try h': {'a': 48, 'e': 0},
#  'ry ha': {'s': 36, 'v': 15, 'p': 14, 'd': 4, 'r': 0},
#  'y has': {' ': 86, '.': 1},
#  'has i': {'t': 18, 'n': 25, 'm': 14, 'd': 1, 'f': 0},
#  'as it': {'s': 26, ' ': 22, '.': 0},
#  's its': {' ': 58, 'e': 2},
#  ' its ': {'o': 51,
#   'a': 15,
#   'i': 17,
#   'e': 15,
#   'w': 8,
#   'g': 10,
#   's': 53,
#   'f': 29,
#   '‘': 0,
#   'b': 18,
#   'l': 11,
#   'd': 24,
#   'v': 13,
#   'p': 43,
#   'y': 3,
#   'm': 11,
#   'c': 38,
#   't': 20,
#   'U': 5,
#   'h': 13,
#   'u': 5,
#   'r': 23,
#   'P': 1,
#   ' ': 0,
#   'S': 5,
#   'E': 0,
#   'B': 2,
#   'j': 4,
#   'n': 10,
#   '7': 4,
#   '1': 0,
#   'k': 1},
#  'its o': {'w': 40,
#   'f': 34,
#   'r': 5,
#   'p': 0,
#   'b': 1,
#   'l': 1,
#   'u': 0,
#   'c': 0,
#   'n': 0,
#   'i': 0},
#  'ts ow': {'n': 40},
#  's own': {' ': 48, '.': 5, 'G': 0},
#  ' own ': {'e': 9,
#   'r': 13,
#   's': 21,
#   'c': 20,
#   'S': 0,
#   'h': 3,
#   'p': 16,
#   'm': 4,
#   'b': 2,
#   'a': 7,
#   'C': 0,
#   'l': 4,
#   'w': 10,
#   't': 2,
#   'K': 0,
#   'i': 6,
#   'j': 0,
#   'f': 4,
#   'I': 1,
#   'd': 1,
#   'g': 5,
#   'v': 2,
#   'A': 0,
#   'M': 0,
#   'o': 0},
#  'own e': {'x': 7, 'a': 1, 'c': 0, 'n': 2},
#  'wn ex': {'p': 7},
#  'n exp': {'e': 24, 'r': 4, 'l': 2, 'a': 10, 'o': 0},
#  'xperi': {'e': 165, 'm': 12},
#  'perie': {'n': 165},
#  'erien': {'c': 165},
#  'rienc': {'e': 157, 'i': 7},
#  'ience': {'s': 33, ',': 33, ' ': 153, '.': 44, '?': 0, 'd': 25, ';': 0},
#  'ences': {',': 7, '.': 7, ' ': 52, ';': 1},
#  'nces,': {' ': 14},
#  'ces, ': {'i': 1,
#   't': 10,
#   'b': 6,
#   'w': 8,
#   'r': 2,
#   'I': 2,
#   'a': 6,
#   'h': 3,
#   'o': 3,
#   's': 6,
#   'd': 2,
#   'f': 2,
#   'A': 0,
#   'c': 2,
#   'k': 0,
#   'n': 0,
#   'g': 1,
#   'e': 1,
#   'N': 0,
#   'y': 0,
#   'u': 0},
#  'es, i': {'t': 17, 'n': 29, 's': 3, 'f': 0, '-': 0},
#  's, it': {'s': 5, ' ': 50, "'": 0},
#  ', its': {' ': 22},
#  'own r': {'e': 16, 'u': 0},
#  'wn re': {'s': 6, 'm': 1, 'g': 1, 'c': 1, 'l': 0, 'q': 0, 'f': 1},
#  'n res': {'o': 51, 'p': 13, 't': 8, 'e': 4, 'u': 4},
#  ' reso': {'u': 173, 'l': 130, 'r': 5, 'n': 3},
#  'resou': {'r': 174},
#  ...}

# %%
seed = "people get together and form a group"
import random

for i in range(500):
    cut = seed[-window : ]
    fqs = freq[cut]
    top_fqs = sorted(fqs.items() , key = lambda x : x[1] , reverse = True)[:3]
    next_ch = random.choice(top_fqs)[0]
    seed += next_ch 
print(seed)
# Out:
# people get together and form a group ‘D’, growth is
# that thanks. Talks areas.
# We wisdom.
# No other is new, though a profoundations taking techniqueness, try in tribe, violational charging them throw us but the security,- Energizing out it wields. Together.
# Will this, welcoming.
# We agreements.
# Today,
# I went attentiary this.... the sensity.
# India and also to trying their
# problem among toward too, thin; before, try angry, the seniors would leaving
# Busine it together, talents. Why? Becauses it.”
# Mahatma” stars. It’s the presiding it
